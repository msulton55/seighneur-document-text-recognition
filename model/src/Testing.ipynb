# %% [markdown]
# # SDTR data testing and evaluation

# %% [markdown]
# ```
# created by: Muhammad Sulton Tauhid
# sources:
#     1. https://stackoverflow.com/questions/44827930/evaluation-in-a-spacy-ner-model
# ```

# %%
import spacy
import json
from spacy import displacy
from IPython.display import display

# %% [markdown]
# # load the model of AJB page 1 and AJB page 2 & 3

# %%
ajb_nlp_model1 = spacy.load("./ajb_1_model/")
ajb_nlp_model23 = spacy.load("./ajb_23_model/")

# %% [markdown]
# # import the test text and save to variable

# %%
doccano_data_ajb_1 = []
doccano_data_ajb_23 = []
spacy_data_ajb_1 = []
spacy_data_ajb_23 = []

with open(r"../../dataset/export/ajb_1_test.jsonl", "r") as read_file:
    for line in read_file:
        data = json.loads(line)
        doccano_data_ajb_1.append(data)

with open(r"../../dataset/export/ajb_23_test.jsonl", "r") as read_file:
    for line in read_file:
        data = json.loads(line)
        doccano_data_ajb_23.append(data)

for entry in doccano_data_ajb_1:
    entities = []
    for e in entry['label']:
        entities.append((e[0], e[1], e[2]))
    spacy_entry = (entry['data'], { "entities": entities })
    spacy_data_ajb_1.append(spacy_entry)
    
for entry in doccano_data_ajb_23:
    entities = []
    for e in entry['label']:
        entities.append((e[0], e[1], e[2]))
    spacy_entry = (entry['data'], { "entities": entities })
    spacy_data_ajb_23.append(spacy_entry)

# %% [markdown]
# # test the data for AJB page 1

# %%
results_test_ajb1 = []

for data in spacy_data_ajb_1:
    doc = ajb_nlp_model1(data[0])
    results_test_ajb1.append(doc)

displacy.render(results_test_ajb1, style='ent', page=True)
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="id">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">AJB1_1989_T_1	dan akan disebutkan dibagian
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     amih binti oy ong pembel jual beli mi1ik adot mengenai tanah hak nomor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">penjual_nama</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     akta jualbeli 89% no 19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">no_ajb</span>
# </mark>
#  06 apr1l 350 jb agr 89 19 kam1s pada hari ini hari tanggal datang menghadap kepada kami aolimadkosasihra camat kepala wilayah kecamatan 9mhmmma olehmenteridalamnegeridengansuratkeputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri wmwwmw19mrwnemer tanggalwm agraria no 101961 bertindak sebagai wwww ditunjuk penjabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no10 kecematan01don 1961 tentang pendaftaran tanah untuk wilayah dengan dihadliri oleh saksisaksi yang kami kenaldiperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini nam d i 35
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gibu rumah tengga mwam pororjam aa13t klwanan kumetran keumrtan c1pond th kotif tanger ong wwaw
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">penjual_pekerjaan</span>
# </mark>
#  dra em hot ind bertintalk ntut dirigondtri dan hotsegat kuya wartn dari amerhum tadp ridan bon robkuapa tgl november 1988wma nama ii mur selanjutnya disebut penjual
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jaka perkasa 19tohun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">pembeli_nama</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wmwma pekorjoon mheryano rto02trh09 wawwwwkatat1f tangorang wwwwwww
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">penjual_kewarganegaraan</span>
# </mark>
#  selanjutnya disebut pembeli para</div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">AJB1_1990_T_2	53 pembeli
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     akta jual beli 361 no cipondoh 19 90
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">no_ajb</span>
# </mark>
#  rabu tanggal 28 maret 1990 pada hari ini datang menghadap kepada saya achmad kosabir ba camat kepala wilayah kecamatan i fon oh oleh menteri dalam negerikepala badan pertanahan nasional dengan surat berdasarkan ketentuan dalam pasal 5 peraturan menteri agraria no 101961 keputusannya tanggal no bertindak sebagai pejabat pembuat akta tanah yang dimaksud dalam diangkat pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kecamatan ipondoh dengan dihadiri oleh saksisaksi yang dikenal oleh saya pejabat pembuat akta tanah dan akan disebutkan di bagian akhir akta ini i
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     n ama songgo bin bregud
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">penjual_nama</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     85 t a h un petan i umur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">penjual_umur</span>
# </mark>
#  pekerjaan
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kewarganegaraan indonesia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">penjual_kewarganegaraan</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a l ama t kpkunciran rt01kw07 kelurahan kunciran kecamatan cipondoh kotif tangerang
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">penjual_alamat</span>
# </mark>
#  selaku penjual untuk selanjutnga di setut pihak pertama
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     satria wibawa 24 t a h u n
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">pembeli_nama</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mahasiswa ii hama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">pembeli_pekerjaan</span>
# </mark>
#  vmur pelkerjean kewargnno paraan indonesia
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a 1 anat j m haryono rt02rw09 kelurahan sukasari kocamatan tangerang kotif tangerang
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">pembeli_alamat</span>
# </mark>
#  selaku pembeli untuk selanjutnya di sebut pifak kedua</div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">AJB1_2008_T_3	51 salinan tpembeli
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     akta jual beli no 1313 2008
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">no_ajb</span>
# </mark>
#  lembar pertamakedua pada hari ini selase a tanggal 25 dua puluh lima bulan nopember tahun 2008 dua ribu delapan hadir dihadapan saya hmasikin wirayudash yang berdasarkan surat keputusan kepala kanwil badan pertanahan nasional pro bantennggal 20062002 nomor 640122002 diangkatditunjuk sebagai pejabat pembuat akta tanah yang selanjutnya disebut ppat yang dimaksud dalam pasal 7 peraturan pemerintah nomor 24 tahun 1997 tentang pendaftaran tanah dengan daerah kerja pinang kunciran jaya kecanatam pinangtangeranglengan dihadiri oleh kecamatan dan berkantor di jlhrrasuna said kelurahan saksisaksi yang saya kenal dan akan disebut pada bagian akhir akta ini i
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tuan ibrohim b hsarim

# %% [markdown]
# # evaluate performance score of AJB page 1

# %%
import pandas as pd
from spacy.scorer import Scorer
from spacy.training.example import Example

examples = []
scorer = Scorer(ajb_nlp_model1)

for text, entities in spacy_data_ajb_1:
    doc = ajb_nlp_model1(text)
    example = Example.from_dict(doc, entities)
    examples.append(example)
    
    result = scorer.score([example])
    
    dataframe_result = pd.json_normalize(result).transpose()
    dataframe_result.columns = ["score"]
    
    print("Data test: {0}".format(text.split("\t")[0]))
    display(dataframe_result)
    print("\n")
    
# evaluation performance of all test text
results = scorer.score(examples)

dataframe_results = pd.json_normalize(results).transpose()
dataframe_results.columns = ['score']

print("Overall data test")
display(dataframe_results)
# Out:
# Data test: AJB1_1989_T_1
#                                          score
# token_acc                                  1.0
# token_p                                    1.0
# token_r                                    1.0
# token_f                                    1.0
# ents_p                                     0.0
# ents_r                                     0.0
# ents_f                                     0.0
# ents_per_type.penjual_nama.p               0.0
# ents_per_type.penjual_nama.r               0.0
# ents_per_type.penjual_nama.f               0.0
# ents_per_type.no_ajb.p                     0.0
# ents_per_type.no_ajb.r                     0.0
# ents_per_type.no_ajb.f                     0.0
# ents_per_type.penjual_pekerjaan.p          0.0
# ents_per_type.penjual_pekerjaan.r          0.0
# ents_per_type.penjual_pekerjaan.f          0.0
# ents_per_type.pembeli_nama.p               0.0
# ents_per_type.pembeli_nama.r               0.0
# ents_per_type.pembeli_nama.f               0.0
# ents_per_type.penjual_kewarganegaraan.p    0.0
# ents_per_type.penjual_kewarganegaraan.r    0.0
# ents_per_type.penjual_kewarganegaraan.f    0.0
# ents_per_type.pembeli_alamat.p             0.0
# ents_per_type.pembeli_alamat.r             0.0
# ents_per_type.pembeli_alamat.f             0.0
# ents_per_type.penjual_umur.p               0.0
# ents_per_type.penjual_umur.r               0.0
# ents_per_type.penjual_umur.f               0.0
# ents_per_type.penjual_alamat.p             0.0
# ents_per_type.penjual_alamat.r             0.0
# ents_per_type.penjual_alamat.f             0.0
# ents_per_type.pembeli_umur.p               0.0
# ents_per_type.pembeli_umur.r               0.0
# ents_per_type.pembeli_umur.f               0.0
# Data test: AJB1_1990_T_2
#                                             score
# token_acc                                1.000000
# token_p                                  1.000000
# token_r                                  1.000000
# token_f                                  1.000000
# ents_p                                   0.625000
# ents_r                                   0.454545
# ents_f                                   0.526316
# ents_per_type.no_ajb.p                   1.000000
# ents_per_type.no_ajb.r                   1.000000
# ents_per_type.no_ajb.f                   1.000000
# ents_per_type.penjual_nama.p             1.000000
# ents_per_type.penjual_nama.r             1.000000
# ents_per_type.penjual_nama.f             1.000000
# ents_per_type.penjual_umur.p             0.000000
# ents_per_type.penjual_umur.r             0.000000
# ents_per_type.penjual_umur.f             0.000000
# ents_per_type.penjual_kewarganegaraan.p  1.000000
# ents_per_type.penjual_kewarganegaraan.r  1.000000
# ents_per_type.penjual_kewarganegaraan.f  1.000000
# ents_per_type.penjual_alamat.p           1.000000
# ents_per_type.penjual_alamat.r           1.000000
# ents_per_type.penjual_alamat.f           1.000000
# ents_per_type.pembeli_nama.p             0.000000
# ents_per_type.pembeli_nama.r             0.000000
# ents_per_type.pembeli_nama.f             0.000000
# ents_per_type.pembeli_pekerjaan.p        0.000000
# ents_per_type.pembeli_pekerjaan.r        0.000000
# ents_per_type.pembeli_pekerjaan.f        0.000000
# ents_per_type.pembeli_alamat.p           1.000000
# ents_per_type.pembeli_alamat.r           1.000000
# ents_per_type.pembeli_alamat.f           1.000000
# ents_per_type.penjual_pekerjaan.p        0.000000
# ents_per_type.penjual_pekerjaan.r        0.000000
# ents_per_type.penjual_pekerjaan.f        0.000000
# ents_per_type.pembeli_kewarganegaraan.p  0.000000
# ents_per_type.pembeli_kewarganegaraan.r  0.000000
# ents_per_type.pembeli_kewarganegaraan.f  0.000000
# ents_per_type.pembeli_umur.p             0.000000
# ents_per_type.pembeli_umur.r             0.000000
# ents_per_type.pembeli_umur.f             0.000000
# Data test: AJB1_2008_T_3
#                                             score
# token_acc                                1.000000
# token_p                                  1.000000
# token_r                                  1.000000
# token_f                                  1.000000
# ents_p                                   0.857143
# ents_r                                   0.923077
# ents_f                                   0.888889
# ents_per_type.no_ajb.p                   0.500000
# ents_per_type.no_ajb.r                   1.000000
# ents_per_type.no_ajb.f                   0.666667
# ents_per_type.penjual_nama.p             1.000000
# ents_per_type.penjual_nama.r             1.000000
# ents_per_type.penjual_nama.f             1.000000
# ents_per_type.penjual_umur.p             1.000000
# ents_per_type.penjual_umur.r             1.000000
# ents_per_type.penjual_umur.f             1.000000
# ents_per_type.penjual_kewarganegaraan.p  0.500000
# ents_per_type.penjual_kewarganegaraan.r  1.000000
# ents_per_type.penjual_kewarganegaraan.f  0.666667
# ents_per_type.penjual_agama.p            1.000000
# ents_per_type.penjual_agama.r            1.000000
# ents_per_type.penjual_agama.f            1.000000
# ents_per_type.penjual_alamat.p           1.000000
# ents_per_type.penjual_alamat.r           1.000000
# ents_per_type.penjual_alamat.f           1.000000
# ents_per_type.pembeli_nama.p             1.000000
# ents_per_type.pembeli_nama.r             1.000000
# ents_per_type.pembeli_nama.f             1.000000
# ents_per_type.pembeli_umur.p             1.000000
# ents_per_type.pembeli_umur.r             1.000000
# ents_per_type.pembeli_umur.f             1.000000
# ents_per_type.pembeli_kewarganegaraan.p  1.000000
# ents_per_type.pembeli_kewarganegaraan.r  1.000000
# ents_per_type.pembeli_kewarganegaraan.f  1.000000
# ents_per_type.pembeli_agama.p            1.000000
# ents_per_type.pembeli_agama.r            1.000000
# ents_per_type.pembeli_agama.f            1.000000
# ents_per_type.pembeli_pekerjaan.p        1.000000
# ents_per_type.pembeli_pekerjaan.r        1.000000
# ents_per_type.pembeli_pekerjaan.f        1.000000
# ents_per_type.pembeli_alamat.p           1.000000
# ents_per_type.pembeli_alamat.r           1.000000
# ents_per_type.pembeli_alamat.f           1.000000
# ents_per_type.penjual_pekerjaan.p        0.000000
# ents_per_type.penjual_pekerjaan.r        0.000000
# ents_per_type.penjual_pekerjaan.f        0.000000
# Overall data test
#                                             score
# token_acc                                1.000000
# token_p                                  1.000000
# token_r                                  1.000000
# token_f                                  1.000000
# ents_p                                   0.629630
# ents_r                                   0.531250
# ents_f                                   0.576271
# ents_per_type.penjual_nama.p             0.666667
# ents_per_type.penjual_nama.r             0.666667
# ents_per_type.penjual_nama.f             0.666667
# ents_per_type.no_ajb.p                   0.500000
# ents_per_type.no_ajb.r                   0.666667
# ents_per_type.no_ajb.f                   0.571429
# ents_per_type.penjual_pekerjaan.p        0.000000
# ents_per_type.penjual_pekerjaan.r        0.000000
# ents_per_type.penjual_pekerjaan.f        0.000000
# ents_per_type.pembeli_nama.p             0.333333
# ents_per_type.pembeli_nama.r             0.333333
# ents_per_type.pembeli_nama.f             0.333333
# ents_per_type.penjual_kewarganegaraan.p  0.500000
# ents_per_type.penjual_kewarganegaraan.r  1.000000
# ents_per_type.penjual_kewarganegaraan.f  0.666667
# ents_per_type.pembeli_alamat.p           1.000000
# ents_per_type.pembeli_alamat.r           0.666667
# ents_per_type.pembeli_alamat.f           0.800000
# ents_per_type.penjual_umur.p             0.500000
# ents_per_type.penjual_umur.r             0.333333
# ents_per_type.penjual_umur.f             0.400000
# ents_per_type.penjual_alamat.p           1.000000
# ents_per_type.penjual_alamat.r           0.666667
# ents_per_type.penjual_alamat.f           0.800000
# ents_per_type.pembeli_umur.p             1.000000
# ents_per_type.pembeli_umur.r             0.333333
# ents_per_type.pembeli_umur.f             0.500000
# ents_per_type.pembeli_pekerjaan.p        0.500000
# ents_per_type.pembeli_pekerjaan.r        0.500000
# ents_per_type.pembeli_pekerjaan.f        0.500000
# ents_per_type.pembeli_kewarganegaraan.p  1.000000
# ents_per_type.pembeli_kewarganegaraan.r  0.500000
# ents_per_type.pembeli_kewarganegaraan.f  0.666667
# ents_per_type.penjual_agama.p            1.000000
# ents_per_type.penjual_agama.r            1.000000
# ents_per_type.penjual_agama.f            1.000000
# ents_per_type.pembeli_agama.p            1.000000
# ents_per_type.pembeli_agama.r            1.000000
# ents_per_type.pembeli_agama.f            1.000000

# %% [markdown]
# # test the data for AJB page 2 & 3

# %%
results_test_ajb23 = []

for data in spacy_data_ajb_23:
    doc = ajb_nlp_model23(data[0])
    results_test_ajb23.append(doc)

displacy.render(results_test_ajb23, style='ent', page=True)
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="id">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">AJB2_1988_T_1	000a 2 para penghadap menerangkan bahwa penjual dengan akta ini menjual kepada pembeli dan pembeli membeli dari penjual sebidang tanah hak 4lik adat
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     no c 3g03
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">no_kohir_girik</span>
# </mark>
#  whahnnindari terletak di daerah tingkat iwilayah daerah tingkat ii wilayah kecamatan wilayah
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     desa kolurahan jawa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">kelurahan_tanah</span>
# </mark>
#  barat
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     taneerang
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">kabupaten_tanah</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cipondoh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">kecamatan_tanah</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     r kunciran no
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">kelurahan_tanah</span>
# </mark>
#  diuraikan dalam surat ukur luas tanah wwseributiga ratus sembilan puluh meter persegi berukuran panjang kuranglebih tgl आ1390 meter meter lebar kuranglebih
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     persil nomor 63siim kohir nomor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">no_persil</span>
# </mark>
#  ka3603 blok dan berbatasan di sebelah tanah milik utara timur selatan ada ada barat ra selanjutnya para penghadap menerangkan bahwa jualbeli ini meliputi pula bagunandentoneman yang ada di atas tanah tersebut yaitu berupa wmtanah konongm 2780000 bahwa jualbeli ini terjadi dengan
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     harga rp i daa jutatujuhratuadalapanpuiuh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">harga_tanah</span>
# </mark>
#  riba rupiah rupiah bahwa penjual mengaku telah menerima sepenuhnya uang pembe lian tersebut di atas dan untuk penerimaan uang itu akta ini berlaku pula sebagai tanda penerimaannya kwitansi bahwa jualbeli ini dilakukan dengan syaratsyarat seperti berikut pasal 1 mulai hari ini tanah hak dan bngunansortetanaman yang diuraikan dalam akta ini telah diserahkan kepada pembeli yang mengaku pula telah merterima penyerahan itu dan segala keuntungan yang didapat dari serta segala kerugianbeban yang diderita atas tanah hak dan banguna sorta taneman tersebut di atas menjadi hak tanggungan pembeli pasal 2 penjual menjamin bahwa tanahhak dan vergunan serta tumman tersebut di atas tidak dikenakan sesuatu sitaan atau tersangkut sebagai tang gungan untuk sesuatu piutang atau diberati dengan bebanbeban lainnya pasal 3</div>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">AJB2_1989_T_2	2 para penghadap menerangkan bahwa penjual dengan akta ini menjual kepada pembeli dan pembeli membeli dari penjual
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     c 246
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">no_kohir_girik</span>
# </mark>
#  sabidang no tanah hak mll1k adat sebahagian dari terletak di daerah tingkat iwilayah daerah tingkat ii wilayah kecamatan wilayah
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jawa berat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">provinsi_tanah</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     clp ond oh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">kecamatan_tanah</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kunciran desa tgl
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">kelurahan_tanah</span>
# </mark>
#  no m2 diuraikan dalam surat ukur luas tanah meter persegi meter erpat ratus n berukuran panjang kuranglebih lebar kuranglebih
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     46 d ii
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">no_persil</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kohir nomor meter blok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">no_kohir_girik</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     persil nomor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">no_persil</span>
# </mark>
#  dan berbatasan di sebelah borbatagan dengen tenah sdr saun berbatagan dengan tener cdrsim berbatagan dengen tamah hy utara timur selatan barat berbatagn dengan tanh 36y hiat selanjutnya para penghadap menerangkan bahwa jualbeli ini meliputi pula bangunan dan tanaman yang ada di atas tanah tersebut yaitu berupa tanah
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     k ogang 1000000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">no_persil</span>
# </mark>
#  bahwa jualbeli ini terjadi dengan
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     harga rp satu jutà rupiah
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">harga_tanah</span>
# </mark>
#  bahwa penjual mengaku telah menerima sepenuhnya uang pembelian tersebut di atas dan untuk penerimaan uang itu akta ini

# %% [markdown]
# # evaluate performance score of AJB page 2 & 3

# %%
examples = []
scorer = Scorer(ajb_nlp_model23)

for text, entities in spacy_data_ajb_23:
    doc = ajb_nlp_model23(text)
    example = Example.from_dict(doc, entities)
    examples.append(example)
    
    result = scorer.score([example]) 
    
    dataframe_result = pd.json_normalize(result).transpose()
    dataframe_result.columns = ["score"]

    
    print("Data test: {0}".format(text.split("\t")[0]))
    display(dataframe_result)
    print("\n")
    
# evaluation performance of all test text
results = scorer.score(examples)

dataframe_results = pd.json_normalize(results).transpose()
dataframe_results.columns = ["score"]


print("Overall data test")
display(dataframe_results)
# Out:
# Data test: AJB2_1988_T_1
# /home/msultont/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/training/iob_utils.py:141: UserWarning: [W030] Some entities could not be aligned in the text "AJB2_1988_T_1	000a 2 para penghadap menerangkan ba..." with entities "[(166, 172, 'no_kohir_girik'), (281, 291, 'provins...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#                                     score
# token_acc                        1.000000
# token_p                          1.000000
# token_r                          1.000000
# token_f                          1.000000
# ents_p                           0.333333
# ents_r                           0.222222
# ents_f                           0.266667
# ents_per_type.no_kohir_girik.p   0.000000
# ents_per_type.no_kohir_girik.r   0.000000
# ents_per_type.no_kohir_girik.f   0.000000
# ents_per_type.kelurahan_tanah.p  0.000000
# ents_per_type.kelurahan_tanah.r  0.000000
# ents_per_type.kelurahan_tanah.f  0.000000
# ents_per_type.kabupaten_tanah.p  1.000000
# ents_per_type.kabupaten_tanah.r  1.000000
# ents_per_type.kabupaten_tanah.f  1.000000
# ents_per_type.kecamatan_tanah.p  1.000000
# ents_per_type.kecamatan_tanah.r  1.000000
# ents_per_type.kecamatan_tanah.f  1.000000
# ents_per_type.no_persil.p        0.000000
# ents_per_type.no_persil.r        0.000000
# ents_per_type.no_persil.f        0.000000
# ents_per_type.harga_tanah.p      0.000000
# ents_per_type.harga_tanah.r      0.000000
# ents_per_type.harga_tanah.f      0.000000
# ents_per_type.luas_tanah.p       0.000000
# ents_per_type.luas_tanah.r       0.000000
# ents_per_type.luas_tanah.f       0.000000
# ents_per_type.provinsi_tanah.p   0.000000
# ents_per_type.provinsi_tanah.r   0.000000
# ents_per_type.provinsi_tanah.f   0.000000
# Data test: AJB2_1989_T_2
#                                     score
# token_acc                        1.000000
# token_p                          1.000000
# token_r                          1.000000
# token_f                          1.000000
# ents_p                           0.555556
# ents_r                           0.555556
# ents_f                           0.555556
# ents_per_type.no_kohir_girik.p   0.500000
# ents_per_type.no_kohir_girik.r   0.500000
# ents_per_type.no_kohir_girik.f   0.500000
# ents_per_type.provinsi_tanah.p   1.000000
# ents_per_type.provinsi_tanah.r   1.000000
# ents_per_type.provinsi_tanah.f   1.000000
# ents_per_type.kecamatan_tanah.p  1.000000
# ents_per_type.kecamatan_tanah.r  1.000000
# ents_per_type.kecamatan_tanah.f  1.000000
# ents_per_type.kelurahan_tanah.p  0.000000
# ents_per_type.kelurahan_tanah.r  0.000000
# ents_per_type.kelurahan_tanah.f  0.000000
# ents_per_type.no_persil.p        0.333333
# ents_per_type.no_persil.r        1.000000
# ents_per_type.no_persil.f        0.500000
# ents_per_type.harga_tanah.p      1.000000
# ents_per_type.harga_tanah.r      0.500000
# ents_per_type.harga_tanah.f      0.666667
# ents_per_type.luas_tanah.p       0.000000
# ents_per_type.luas_tanah.r       0.000000
# ents_per_type.luas_tanah.f       0.000000
# Data test: AJB2_1990_T_3
#                                     score
# token_acc                        1.000000
# token_p                          1.000000
# token_r                          1.000000
# token_f                          1.000000
# ents_p                           0.666667
# ents_r                           0.600000
# ents_f                           0.631579
# ents_per_type.no_persil.p        1.000000
# ents_per_type.no_persil.r        1.000000
# ents_per_type.no_persil.f        1.000000
# ents_per_type.no_kohir_girik.p   1.000000
# ents_per_type.no_kohir_girik.r   1.000000
# ents_per_type.no_kohir_girik.f   1.000000
# ents_per_type.kelurahan_tanah.p  0.500000
# ents_per_type.kelurahan_tanah.r  0.500000
# ents_per_type.kelurahan_tanah.f  0.500000
# ents_per_type.provinsi_tanah.p   1.000000
# ents_per_type.provinsi_tanah.r   1.000000
# ents_per_type.provinsi_tanah.f   1.000000
# ents_per_type.kabupaten_tanah.p  1.000000
# ents_per_type.kabupaten_tanah.r  1.000000
# ents_per_type.kabupaten_tanah.f  1.000000
# ents_per_type.kecamatan_tanah.p  1.000000
# ents_per_type.kecamatan_tanah.r  1.000000
# ents_per_type.kecamatan_tanah.f  1.000000
# ents_per_type.harga_tanah.p      0.000000
# ents_per_type.harga_tanah.r      0.000000
# ents_per_type.harga_tanah.f      0.000000
# ents_per_type.luas_tanah.p       0.000000
# ents_per_type.luas_tanah.r       0.000000
# ents_per_type.luas_tanah.f       0.000000
# Data test: AJB2_2008_T_4
# /home/msultont/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/training/iob_utils.py:141: UserWarning: [W030] Some entities could not be aligned in the text "AJB2_2008_T_4	4034323642pp para penghadap dikenal ..." with entities "[(919, 936, 'no_persil'), (936, 963, 'no_kohir_gir...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#                             score
# token_acc                     1.0
# token_p                       1.0
# token_r                       1.0
# token_f                       1.0
# ents_p                        1.0
# ents_r                        1.0
# ents_f                        1.0
# ents_per_type.no_persil.p     0.0
# ents_per_type.no_persil.r     0.0
# ents_per_type.no_persil.f     0.0
# ents_per_type.luas_tanah.p    1.0
# ents_per_type.luas_tanah.r    1.0
# ents_per_type.luas_tanah.f    1.0
# Data test: AJB3_2008_T_5
# /home/msultont/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/training/iob_utils.py:141: UserWarning: [W030] Some entities could not be aligned in the text "AJB3_2008_T_5	sebagaimana diuraikan dalam peta tan..." with entities "[(133, 147, 'no_kohir_girik'), (148, 159, 'no_pers...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#                                  score
# token_acc                          1.0
# token_p                            1.0
# token_r                            1.0
# token_f                            1.0
# ents_p                             1.0
# ents_r                             1.0
# ents_f                             1.0
# ents_per_type.no_kohir_girik.p     0.0
# ents_per_type.no_kohir_girik.r     0.0
# ents_per_type.no_kohir_girik.f     0.0
# ents_per_type.no_persil.p          1.0
# ents_per_type.no_persil.r          1.0
# ents_per_type.no_persil.f          1.0
# ents_per_type.provinsi_tanah.p     1.0
# ents_per_type.provinsi_tanah.r     1.0
# ents_per_type.provinsi_tanah.f     1.0
# ents_per_type.kabupaten_tanah.p    1.0
# ents_per_type.kabupaten_tanah.r    1.0
# ents_per_type.kabupaten_tanah.f    1.0
# ents_per_type.kecamatan_tanah.p    1.0
# ents_per_type.kecamatan_tanah.r    1.0
# ents_per_type.kecamatan_tanah.f    1.0
# ents_per_type.kelurahan_tanah.p    1.0
# ents_per_type.kelurahan_tanah.r    1.0
# ents_per_type.kelurahan_tanah.f    1.0
# ents_per_type.jalan_tanah.p        1.0
# ents_per_type.jalan_tanah.r        1.0
# ents_per_type.jalan_tanah.f        1.0
# ents_per_type.harga_tanah.p        1.0
# ents_per_type.harga_tanah.r        1.0
# ents_per_type.harga_tanah.f        1.0
# Overall data test
#                                     score
# token_acc                        1.000000
# token_p                          1.000000
# token_r                          1.000000
# token_f                          1.000000
# ents_p                           0.656250
# ents_r                           0.583333
# ents_f                           0.617647
# ents_per_type.no_kohir_girik.p   0.500000
# ents_per_type.no_kohir_girik.r   0.400000
# ents_per_type.no_kohir_girik.f   0.444444
# ents_per_type.kelurahan_tanah.p  0.333333
# ents_per_type.kelurahan_tanah.r  0.400000
# ents_per_type.kelurahan_tanah.f  0.363636
# ents_per_type.kabupaten_tanah.p  1.000000
# ents_per_type.kabupaten_tanah.r  1.000000
# ents_per_type.kabupaten_tanah.f  1.000000
# ents_per_type.kecamatan_tanah.p  1.000000
# ents_per_type.kecamatan_tanah.r  1.000000
# ents_per_type.kecamatan_tanah.f  1.000000
# ents_per_type.no_persil.p        0.600000
# ents_per_type.no_persil.r        1.000000
# ents_per_type.no_persil.f        0.750000
# ents_per_type.harga_tanah.p      0.400000
# ents_per_type.harga_tanah.r      0.333333
# ents_per_type.harga_tanah.f      0.363636
# ents_per_type.luas_tanah.p       1.000000
# ents_per_type.luas_tanah.r       0.200000
# ents_per_type.luas_tanah.f       0.333333
# ents_per_type.provinsi_tanah.p   1.000000
# ents_per_type.provinsi_tanah.r   0.750000
# ents_per_type.provinsi_tanah.f   0.857143
# ents_per_type.jalan_tanah.p      1.000000
# ents_per_type.jalan_tanah.r      1.000000
# ents_per_type.jalan_tanah.f      1.000000
