# %% [markdown]
# # Data Preparation

# %%
import json

# %%
labeled_data_ajb_1 = []     # data preparation for AJB document page one
labeled_data_ajb_23 = []    # data preparation for AJB document page two
training_data_ajb_1 = []    # data convertion from doccano into spacy variable for AJB document page one
training_data_ajb_23 = []   # data convertion from doccano into spacy variable for AJB document page two

# %%
# read AJB document page one file
with open(r"../../dataset/export/ajb_1.jsonl", "r") as read_file:
    for line in read_file:
        data = json.loads(line)
        labeled_data_ajb_1.append(data)

# read AJB document page two and three file
with open(r"../../dataset/export/ajb_23.jsonl", "r") as read_file:
    for line in read_file:
        data = json.loads(line)
        labeled_data_ajb_23.append(data)

# %%
# convert AJB document page one labeled_data doccano version into training_data spacy version
for entry in labeled_data_ajb_1:
    entities = []
    for e in entry['label']:
        entities.append((e[0], e[1], e[2]))
    spacy_entry = (entry['data'], { "entities": entities })
    training_data_ajb_1.append(spacy_entry)
    
# convert AJB document page two and three labeled_data doccano version into training_data spacy version
for entry in labeled_data_ajb_23:
    entities = []
    for e in entry['label']:
        entities.append((e[0], e[1], e[2]))
    spacy_entry = (entry['data'], { "entities": entities })
    training_data_ajb_23.append(spacy_entry)

# %%
training_data_ajb_1
# Out:
# [('AJB1_1988_R_1\tmengenai jual bali ml ik adat tanah hak nomor c3603 akta jualbeli no1382jragr 19 88 pada hari ini hari selaga tanggal 15 nopamber 1988 datang menghadap kepada kami camat kepala wilayah kecamatan gapond0 h olementert dan negei uengan surarkeputusamya berdasarkan ketentuan dalam pasal 5 peraturan menteri tangga agraria no 101961 bertindak sebagai m m lthi han afig ra nomor dije penjabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kebupaten daerah tinskatttnearane dengan dihadliri oleh saksisaksi yang kami kenaldiperkenalkan kepada kami dan akan dise butkan dibagian akhir akta ini i naa u m ur ny tinaw ati 48 tahun 1tbu rumattanggam indonesia aesoleh al1 rt004014kelura han sukasari kecamatan tangerang kota administratif tangerang pakerjaan kownhemegarwn aa at selanjutnya disebut peninal 1 jaka pihrkasa n a a a ii u m u 19tal 19 tahun pelada i indonosia 1 j1mtharypno rt00209 kelurahan sukanari kooamatan tangerang kota 2 adurinistratif tangerang pelcerjean 21 kewargmegam a1 a ma selanjutnya disebut pembeli para',
#   {'entities': [(66, 97, 'no_ajb'),
#     (710, 718, 'penjual_umur'),
#     (719, 736, 'penjual_pekerjaan'),
#     (737, 746, 'penjual_kewarganegaraan'),
#     (747, 835, 'penjual_alamat'),
#     (896, 917, 'pembeli_nama'),
#     (921, 941, 'pembeli_umur'),
#     (942, 948, 'pembeli_pekerjaan'),
#     (950, 960, 'pembeli_kewarganegaraan'),
#     (963, 1053, 'pembeli_alamat'),
#     (697, 709, 'penjual_nama')]}),
#  ('AJB1_1989_R_1\t13 pembelĭ mengenai jual beli tanah hak milike adat nomor akta jualbeli 358 jb nọ kamis agr 89 19 06 april datang menghadap kepada kami aclimakosasihba camat kepala wilayah kecamatan pada hari ini hari 89 19 tanggal cipondo h olehmenteridalamnegeridengansuratkeputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri he en tanggalw w agraria no 101961 bertindak sebagai wwww19ynemorm ditunjuk penjabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no10 kecamatan cipondron 1961 tentang pendaftaran tanah untuk wilayah dengan dihadliri oleh saksisaksi yang kami kenaldiperkenalkan kepada kami dan akan dise butkan dibagian akhir a m a i akta n n manih binti oy ong ibu rumah tangga uwww pekerjaam kewarganegarann indanesta ei kampung kmciram rto0rrwoo3 kelranan kumciran kecamatan cipond th kotif tangerang wa ded am hatint bertindak untut diri gendirf dan besagat kuaga waris darf aimerhum taip riđan geguet rat kuagatgt november 1988g waw selanjutnya disebut penjual s jaka perkasa nama ii wun6ts inun pekerjean pelajar kewarganegaraan indđ che gin ja1 amat heryano rioc2ah09 terurahan sukagari kecamatan tangerang kotatif tangerang selanjutnya disebut pembeli para',
#   {'entities': [(72, 111, 'no_ajb'),
#     (690, 712, 'penjual_nama'),
#     (713, 729, 'penjual_pekerjaan'),
#     (745, 770, 'penjual_kewarganegaraan'),
#     (774, 854, 'penjual_alamat'),
#     (1019, 1036, 'pembeli_nama'),
#     (1052, 1069, 'pembeli_pekerjaan'),
#     (1070, 1094, 'pembeli_kewarganegaraan'),
#     (1099, 1182, 'pembeli_alamat')]}),
#  ('AJB1_1990_R_1\tpembeli akta jual beli 361 no cipondoh 1990 rabu tanggal 28 maret 1990 pada hari ini datang menghadap kepada saya achmad kosasir ba camat kepala wilayah kecamatan i f ondoh oleh menteri dalam negerikepala badan pertanahan nasional dengan surat berdasarkan ketentuan dalam pasal 5 peraturan menteri agraria no 101961 keputusannya tanggal no bertindak sebagai pejabat pembuat akta tanah yang dimaksud dalam diangkat pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kecamatan cipondoh dengan dihadiri oleh saksisaksi yang dikenal oleh saya pejabat pembuat akta tanah dan akan disebutkan di bagian akhir akta ini i nama songgo bin bregud 85 t ahun petani umur pekerjaan kewarganegaraan indonesia kpkunciran rt01rw07 kelurahan kunciran kecamatan ciponloh kotif tangerang a lama t selaku penjual untuk selanjutnga di setut pihak pertama satria wibawa ii tama 24 t a h u n vmur mahasiswa pekerjean kewargane paraan ind onesia jh m haryono rt02rw09 kelurahan sukasari a 1amat kecamatan tangerang kotif tangarang selaku pembeli untuk selanjutnya di sebut pifak kedua',
#   {'entities': [(22, 57, 'no_ajb'),
#     (663, 685, 'penjual_nama'),
#     (686, 695, 'penjual_umur'),
#     (696, 702, 'penjual_pekerjaan'),
#     (718, 743, 'penjual_kewarganegaraan'),
#     (744, 826, 'penjual_alamat'),
#     (883, 904, 'pembeli_nama'),
#     (905, 922, 'pembeli_umur'),
#     (923, 942, 'pembeli_pekerjaan'),
#     (943, 970, 'pembeli_kewarganegaraan'),
#     (971, 1055, 'pembeli_alamat')]}),
#  ('AJB1_2008_R_1\t51 salinan pembeli akta jual beli no 1313 i 2008 lembar pertamakedua pada hari ini selase tanggal 25 dua puluh lima tahun 2008 dua ribu delapan bulan nopember hadir dihadapan saya hmasikin wirayuda sh yang berdasarkan surat keputusan kepala kanw1l badan pertanahan nasional probantennggal 20062002 nomor 640122002 diangkatditunjuk sebagai pejabat pembuat akta tanah yang selanjutnya disebut ppat yang dimaksud dalam pasal 7 peraturan pemerintah nomor 24 tahun 1997 tentang pendaftaran tanah dengan daerah kerja kecamatan pinang kunciran jaya kecanatan pinangtangeranglengan dihadiri oleh dan berkantor di jlhrrasuna said kelurahan saksisaksi yang saya kenal dan akan disebut pada bagian akhir akta ini i tuan ibrohim b hsarim lahir tangerang8 agustus 1963 warga negara indonesia agama isla pekerjaan karyawan swasta bertempat tinggal rukun tetangga 02 rukun werga 03 kelurahan kunciran jaya kecamatan pinang kota tangerang propinsi banten dalam hal ini bertindak sebagai kuasa waris dari almarhum tuanhsarīmb djiman sesuai surat kuasa waris dan surat keterang an waris nomor 595558kemasykj2008 tanggal 13 nopenber 2003 selaku penjualselanjutnya disebut pihak pertama ii tuans w ahyudi n lahir tangerang 20 mei 1975 warga negara indonesia agama islam pekerjaan pegawai swasta bertempat tinggal jalan mt haryono rukun tetangga 02 rukun warga 09 kelurahan sukasari kecamatan tangerang kota tangerang propinsi banten selaku pembeliselanjutnya disebut pihak kedua halaman i dari7 akta jual bell',
#   {'entities': [(33, 62, 'no_ajb'),
#     (718, 739, 'penjual_nama'),
#     (740, 769, 'penjual_umur'),
#     (770, 792, 'penjual_pekerjaan'),
#     (793, 803, 'penjual_agama'),
#     (804, 829, 'penjual_kewarganegaraan'),
#     (830, 952, 'penjual_alamat'),
#     (1184, 1200, 'pembeli_nama'),
#     (1201, 1228, 'pembeli_umur'),
#     (1229, 1251, 'pembeli_kewarganegaraan'),
#     (1252, 1263, 'pembeli_agama'),
#     (1264, 1288, 'pembeli_pekerjaan'),
#     (1289, 1426, 'pembeli_alamat')]}),
#  ('AJB1_1988_D_1\tmengenai jual bali tanah hak ml ik adat nomor 3003 akta jualbeli no596 jbagr 8819 pada hari ini hari selasa tanggal 15 november 1988 datang menghadap kepada kami m luthfi hanafie ba camat kepala wilayah kecamatan cipondoh oleh menteri dalam negeri dengan surat keputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri tanggal 10 nomor agraria no 10 1961 bertindak 1 sebagai ditunjuk pejabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kabupaten daerah tingkat ii tangerang dengan dihadiri oleh saksi saksi yang kami kenal  diperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini i naa u m ur ny sumar1yiti 66 tahun ibu rumahtangga indonesia jalan hr rasuna said nomor a5 08 bintaro pondok aren tangerang selatan pakerjaan kownhemegarwn aa at selanjutnya disebut peninal 1 jaka pihrkasa n a a a ii u m u 19tal 19 tahun pelajar indonosia 1 j1mtharypno rt00209 kelurahan sukanari kooamatan tangerang kota 2 adurinistratif tangerang pelcerjean 21 kewargmegam a1 a ma selanjutnya disebut pembeli para',
#   {'entities': [(65, 95, 'no_ajb'),
#     (715, 728, 'penjual_nama'),
#     (729, 737, 'penjual_umur'),
#     (738, 753, 'penjual_pekerjaan'),
#     (764, 834, 'penjual_alamat'),
#     (895, 916, 'pembeli_nama'),
#     (920, 940, 'pembeli_umur'),
#     (941, 948, 'pembeli_pekerjaan'),
#     (949, 958, 'pembeli_kewarganegaraan'),
#     (961, 1051, 'pembeli_alamat'),
#     (754, 763, 'penjual_kewarganegaraan')]}),
#  ('AJB1_1988_D_2\tmengenai jual beli milik adat tanah hak nomor c 24 03 beli akta jual no1382jragr 19 88 pada hari ini hari selasa tanggal 15 november 1988 datang menghadap kepada kami camat kepala wilayah kecamatan cipondoh h menteri dan negeri dengan surat keputusan berdasarkan ketentuan dalam pasal 5 peraturan menteri tangga agraria no 101961 bertindak 1 sebagai m m lahir dan afig ra 1 nomor dije pejabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kabupaten daerah tinskatttnearane dengan dihadiri oleh saksi saksi yang kami diperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini i nama umur ny sudrajat 42 tahun pegawai ngeiri indonesia jalan rawa buntu utara sektor i2 blok ua nomor 26 27 serpong tangerang selatan pekerjaan kewarganegaraan alamat selanjutnya disebut penjual 1 candra dimuka nama su aih uu um ur 22 tahun mahasiswa indonesia 1 villa dago pamulang tangerang pekerjaan 21 kewarganegaraan ada selanjutnya disebut pembeli para',
#   {'entities': [(73, 100, 'no_ajb'),
#     (695, 706, 'penjual_nama'),
#     (707, 715, 'penjual_umur'),
#     (716, 730, 'penjual_pekerjaan'),
#     (731, 740, 'penjual_kewarganegaraan'),
#     (740, 819, 'penjual_alamat'),
#     (883, 901, 'pembeli_nama'),
#     (912, 926, 'pembeli_umur'),
#     (927, 936, 'pembeli_pekerjaan'),
#     (937, 946, 'pembeli_kewarganegaraan'),
#     (949, 978, 'pembeli_alamat')]}),
#  ('AJB1_1988_D_3\tmengenai jual beli tanah hak milik adat nomor c 123 akta beli no 866 jual jb agr 1988 pada hari ini hari selasa tanggal 15 november 1988 datang menghadap kepada kami m luthfi hanafie ba camat kepala wilayah kecamatan cipondoh oleh menteri dalam negeri dengan surat keputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri tanggal 10 nomor agraria no 10 1961 bertindak 1 sebagai ditunjuk pejabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kabupaten daerah tingkat ii tangerang dengan dihadiri oleh saksi saksi yang kami kenal  diperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini nama ny sumariyaningsih umur 50 tahun pekerjaan pedagang indonesia kewarganegaraan alamat jl kh soleh ali rt 004 014 kelurahan sukasari kecamatan tangerang kota administratif tangerang selanjutnya disebut penjual nama akbar t 4an jung umur 28 tahun pekerjaan barista kewarganegaraan indo0neaesia alamat jl raya imam bonjol 42d tangerang selanjutnya disebut pembeli para',
#   {'entities': [(66, 99, 'no_ajb'),
#     (711, 729, 'penjual_nama'),
#     (730, 743, 'penjual_umur'),
#     (744, 762, 'penjual_pekerjaan'),
#     (763, 788, 'penjual_kewarganegaraan'),
#     (789, 890, 'penjual_alamat'),
#     (919, 940, 'pembeli_nama'),
#     (941, 954, 'pembeli_umur'),
#     (954, 972, 'pembeli_pekerjaan'),
#     (973, 1001, 'pembeli_kewarganegaraan'),
#     (1002, 1042, 'pembeli_alamat')]}),
#  ('AJB1_1988_D_4\tmengenai jualbali tanah hak mlik adat nomor c 03 11 akta jualbali no 1999 1988 agrjb pada hari ini hari selasa tanggal 15 november 1988 datang menghadap kepada kami m luthfi hanafie ba camat kepala wilayah kecamatan cipondoh oleh menteri dalam negeri dengan surat keputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri tanggal 10 nomor agraria no 10 1961 bertindak 1 sebagai ditunjuk pejabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kabupaten daerah tingkat ii tangerang dengan dihadiri oleh saksi saksi yang kami kenal  diperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini i nama u m u r sutoy 0 48 tahun p3lkeajean pedgeang keworgmean indooneesai alamat jalan otista raya nomor 3 ciputat tangerang selatan selanjutnya disebut penjual n aa wahyudin u m u 24 tahun pekerjaan pegawai negerisipil keworgnmwm indonesia a l mat kompl regency melati mas bl c 15 3 tangerang selanjutnya disebut pembeli para',
#   {'entities': [(66, 98, 'no_ajb'),
#     (720, 727, 'penjual_nama'),
#     (728, 736, 'penjual_umur'),
#     (737, 756, 'penjual_pekerjaan'),
#     (757, 779, 'penjual_kewarganegaraan'),
#     (780, 838, 'penjual_alamat'),
#     (872, 880, 'pembeli_nama'),
#     (881, 895, 'pembeli_umur'),
#     (896, 925, 'pembeli_pekerjaan'),
#     (926, 946, 'pembeli_kewarganegaraan'),
#     (947, 999, 'pembeli_alamat')]}),
#  ('AJB1_1988_D_5\tmengenai jual bali tanah hak ml ik adat nomor 3603 akta belijual no1382 1988 jb agr pada hari ini hari selasa tanggal 15 november 1988 datang menghadap kepada kami m luthfi hanafie ba camat kepala wilayah kecamatan cipondoh oleh menteri dalam negeri dengan surat keputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri tanggal 10 nomor agraria no 10 1961 bertindak 1 sebagai ditunjuk pejabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kabupaten daerah tingkat ii tangerang dengan dihadiri oleh saksi saksi yang kami kenal  diperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini i naa u m ur ibr4him mukti 31 tahun audit0r indonesia jalan boulevard bintaro jaya nomor 1 pondok aren tangerang selatan pakerjaan kownhemegarwn aa at selanjutnya disebut penjual mega kurnia n a a a ii u m u 28tal 19 tahun pengusaha indonosia 1 kompl permata pamulang bl i2 16 rt 01 04 tangerang pelcerjean 21 kewargmegam a1 a ma selanjutnya disebut pembeli para',
#   {'entities': [(65, 97, 'no_ajb'),
#     (717, 730, 'penjual_nama'),
#     (731, 739, 'penjual_umur'),
#     (740, 747, 'penjual_pekerjaan'),
#     (748, 757, 'penjual_kewarganegaraan'),
#     (758, 824, 'penjual_alamat'),
#     (883, 902, 'pembeli_nama'),
#     (906, 926, 'pembeli_umur'),
#     (927, 936, 'pembeli_pekerjaan'),
#     (937, 946, 'pembeli_kewarganegaraan'),
#     (949, 999, 'pembeli_alamat')]}),
#  ('AJB1_1988_D_6\tmengenai jual bali tanah hak ml ik adat nomor 36 03 c akta jualbeli jbagr no 382 19 88 pada hari ini hari selasa tanggal 15 november 1988 datang menghadap kepada kami m luthfi hanafie ba camat kepala wilayah kecamatan cipondoh oleh menteri dalam negeri dengan surat keputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri tanggal 10 nomor agraria no 10 1961 bertindak 1 sebagai ditunjuk pejabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kabupaten daerah tingkat ii tangerang dengan dihadiri oleh saksi saksi yang kami kenal  diperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini i naa u m ur retno muluk 29 tahun pedagang indonesia jalan moh husni thamrin nomor 1 pondok aren tangerang selatan pakerjaan kownhemegarwn aa at selanjutnya disebut penjual ahmad dzak y n a a a ii u m u  29 tahun wiraswasta indonosia 1 jl melati iii vila melati mas bl j3 11 tangerang pelcerjean 21 kewargmegam a1 a ma selanjutnya disebut pembeli para',
#   {'entities': [(68, 100, 'no_ajb'),
#     (720, 731, 'penjual_nama'),
#     (732, 740, 'penjual_umur'),
#     (741, 749, 'penjual_pekerjaan'),
#     (749, 759, 'penjual_kewarganegaraan'),
#     (760, 821, 'penjual_alamat'),
#     (880, 900, 'pembeli_nama'),
#     (904, 919, 'pembeli_umur'),
#     (920, 930, 'pembeli_pekerjaan'),
#     (931, 940, 'pembeli_kewarganegaraan'),
#     (943, 991, 'pembeli_alamat')]}),
#  ('AJB1_1988_D_7\tmengenai jual beli tanah hak milik adat nomor c 0336  akta jual beli no 78 agr jb 88 19 pada hari ini hari selasa tanggal 15 november 1988 datang menghadap kepada kami m luthfi hanafie ba camat kepala wilayah kecamatan cipondoh oleh menteri dalam negeri dengan surat keputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri tanggal 10 nomor agraria no 10 1961 bertindak 1 sebagai ditunjuk pejabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kabupaten daerah tingkat ii tangerang dengan dihadiri oleh saksi saksi yang kami kenal diperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini i nama muhamad arifin umur 23 tahun pekerjaan karyawan bank kewarganegaraan indonesia alamat jalan alam sutera boulevard nomor kav25 serpong utara tangerang selatan selanjutnya disebut penjual nama jaka pihrkasa u m ur 19 tahun pekerjaan pelajar kewarganegaraan indonesia alamat jl mt haryono rt 002 09 kelurahan sukasari kecamatan tangerang kota 2 administratif tangerang selanjutnya disebut pembeli para',
#   {'entities': [(68, 101, 'no_ajb'),
#     (709, 728, 'penjual_nama'),
#     (729, 742, 'penjual_umur'),
#     (743, 766, 'penjual_pekerjaan'),
#     (767, 792, 'penjual_kewarganegaraan'),
#     (793, 871, 'penjual_alamat'),
#     (900, 918, 'pembeli_nama'),
#     (919, 934, 'pembeli_umur'),
#     (935, 952, 'pembeli_pekerjaan'),
#     (953, 978, 'pembeli_kewarganegaraan'),
#     (979, 1079, 'pembeli_alamat')]}),
#  ('AJB1_1988_D_8\tmengenai jual beli tanah hak milik adat nomor c 123o akta jual beli no 1162 jb agr 1988 pada hari ini hari selasa tanggal 15 november 1988 datang menghadap kepada kami m luthfi hanafie ba camat kepala wilayah kecamatan cipondoh oleh menteri dalam negeri dengan surat keputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri tanggal 10 nomor agraria no 10 1961 bertindak 1 sebagai ditunjuk pejabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kabupaten daerah tingkat ii tangerang dengan dihadiri oleh saksi saksi yang kami kenal diperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini i so0ng g0 bin alif nama 45 tahun u mur karyawan pel0ekejan indonesia kewarganegaraan jl padat karya km 07 curug tangerang kota administratif tangerang alamat selanjutnya disebut penjual akbar perk4asa nama 39 tahun u m ur pengusaha minyak pekerjaan indonesia kewarganegaraan jl raya pasar kamis kompl bumi indah bl rc 15 rt 001 13 tangerang selanjutnya disebut pembeli para',
#   {'entities': [(67, 101, 'no_ajb'),
#     (709, 731, 'penjual_nama'),
#     (732, 746, 'penjual_umur'),
#     (747, 766, 'penjual_pekerjaan'),
#     (766, 792, 'penjual_kewarganegaraan'),
#     (793, 865, 'penjual_alamat'),
#     (894, 913, 'pembeli_nama'),
#     (914, 929, 'pembeli_umur'),
#     (930, 956, 'pembeli_pekerjaan'),
#     (957, 982, 'pembeli_kewarganegaraan'),
#     (983, 1048, 'pembeli_alamat')]}),
#  ('AJB1_1988_D_9\tmengenai jualbeli tanah hak mi ik adat nomor 38 co3 akta jualbali 62jbagr no 88 19 pada hari ini hari selasa tanggal 15 november 1988 datang menghadap kepada kami m luthfi hanafie ba camat kepala wilayah kecamatan c1pondth olehmenteridalamnegeri dengan suratkeputusannya berdasarkan ketentuan dalam pasal 5 menteri peraturan tanggal 10 nomor agraria no 10 1961 bertindak 1 sebagai ditunjuk pejabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kabupaten daerah tingkat ii tangerang dengan dihadiri oleh saksi saksi yang kami kenal diperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini i ilham wicaksana nama 27tah u mur pegawai negeri sipil pekerajan indonesia kewarganegaraan a al jlp4lam rya no13 blokx1 perumnas cibodas cibdasari tangerang aal tam selanjutnya disebut penjual jaka pihrkasa nama 19 tahun u m ur pelajar pekerjaan indonesia kewarganegaraan jl mt haryono rt 002 09 kelurahan sukasari kecamatan alamat tangerang kota 2 administratif tangerang selanjutnya disebut pembeli para',
#   {'entities': [(66, 96, 'no_ajb'),
#     (700, 720, 'penjual_nama'),
#     (721, 732, 'penjual_umur'),
#     (733, 763, 'penjual_pekerjaan'),
#     (764, 789, 'penjual_kewarganegaraan'),
#     (790, 863, 'penjual_alamat'),
#     (892, 910, 'pembeli_nama'),
#     (911, 926, 'pembeli_umur'),
#     (927, 944, 'pembeli_pekerjaan'),
#     (945, 970, 'pembeli_kewarganegaraan'),
#     (971, 1071, 'pembeli_alamat')]}),
#  ('AJB1_1988_D_10\tmengenai jual beli tanah hak milik adat nomor c 0387 akta jualbali no1339 1989 pada hari ini hari selasa tanggal 15 november 1988 datang menghadap kepada kami m luthfi hanafie ba camat kepala wilayah kecamatan c1pondth olehmenteridalamnegeri dengan suratkeputusannya berdasarkan ketentuan dalam pasal 5 menteri peraturan tanggal 10 nomor agraria no 10 1961 bertindak 1 sebagai ditunjuk pejabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kabupaten daerah tingkat ii tangerang dengan dihadiri oleh saksi saksi yang kami kenal diperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini na aaa um uur pelakejan i maulana ibr14him nama 22tah maha siwa indonesia kewarganegaraan a alat jl pulau put4 ri utra rt0010 rw 001 kelurahan kelpad indah kecamatan tangerang kota administratif tangerang aal tam selanjutnya disebut penjual wah yudin nama 19 tahun u m ur mahasiswa pekerjaan indonesia kewarganegaraan jl benteng betwatwi ruko cendana taman royal no 40 rt 002 09 kelurahan tanah tinggi kecamatan tangerang kota 2 administratif tangerang alamat selanjutnya disebut pembeli para',
#   {'entities': [(68, 93, 'no_ajb'),
#     (721, 742, 'penjual_nama'),
#     (743, 748, 'penjual_umur'),
#     (749, 758, 'penjual_pekerjaan'),
#     (759, 784, 'penjual_kewarganegaraan'),
#     (785, 907, 'penjual_alamat'),
#     (936, 950, 'pembeli_nama'),
#     (951, 966, 'pembeli_umur'),
#     (967, 986, 'pembeli_pekerjaan'),
#     (987, 1012, 'pembeli_kewarganegaraan'),
#     (1013, 1154, 'pembeli_alamat')]}),
#  ('AJB1_1989_D_1\tmengenai jual beli tanah hak milike adat nomor akta jualbeli 358 jb nọ kamis agr 89 19 06 april datang menghadap kepada kami aclimakosasihba camat kepala wilayah kecamatan pada hari ini hari 89 19 tanggal cipondo h olehmenteridalamnegeridengansuratkeputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri he en tanggalw w agraria no 101961 bertindak sebagai wwww19ynemorm ditunjuk penjabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no10 kecamatan cipondron 1961 tentang pendaftaran tanah untuk wilayah dengan dihadliri oleh saksisaksi yang kami kenaldiperkenalkan kepada kami dan akan dise butkan dibagian akhir a m a i rini binti sukatma 13 pembelĭ n n ibu rumah tangga uwww pekerjaam kewarganegarann indanesta ei kampung kmciram rto0rrwoo3 kelranan kumciran kecamatan cipond th kotif tangerang wa ded am hatint bertindak untut diri gendirf dan besagat kuaga waris darf aimerhum taip riđan geguet rat kuagatgt november 1988g waw selanjutnya disebut penjual s ahmad dzaky nama ii wun6ts inun pekerjean pelajar kewarganegaraan indđ che gin ja1 amat heryano rioc2ah09 terurahan sukagari kecamatan tangerang kotatif tangerang selanjutnya disebut pembeli para',
#   {'entities': [(61, 100, 'no_ajb'),
#     (674, 692, 'penjual_nama'),
#     (708, 739, 'penjual_pekerjaan'),
#     (740, 765, 'penjual_kewarganegaraan'),
#     (769, 849, 'penjual_alamat'),
#     (1014, 1030, 'pembeli_nama'),
#     (1046, 1063, 'pembeli_pekerjaan'),
#     (1064, 1088, 'pembeli_kewarganegaraan'),
#     (1093, 1176, 'pembeli_alamat')]}),
#  ('AJB1_1989_D_2\tmengenai jual beli tanah hak milike adat nomor akta jualbali 1278 jb n0 kamis agr 89 19 06 april datang menghadap kepada kami aclimakosasihba camat kepala wilayah kecamatan pada hari ini hari 89 19 tanggal cipondo h olehmenteridalamnegeridengansuratkeputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri he en tanggalw w agraria no 101961 bertindak sebagai wwww19ynemorm ditunjuk penjabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no10 kecamatan cipondron 1961 tentang pendaftaran tanah untuk wilayah dengan dihadliri oleh saksisaksi yang kami kenaldiperkenalkan kepada kami dan akan dise butkan dibagian akhir a m a i su pard1 h4j1sul 13 karyawan bank uwww pekerjaam kewarganegarann indanesta ei kawasan millenium industrial estate jl millenium 23 blok o2 no2a tigaraksa cikupa tangerang wa ded am hatint bertindak untut diri gendirf dan besagat kuaga waris darf aimerhum taip riđan geguet rat kuagatgt november 1988g waw selanjutnya disebut penjual s bima arya nama ii wun6ts inun pekerjean pelajar kewarganegaraan indđ che gin ja1 amat heryano rioc2ah09 terurahan sukagari kecamatan tangerang kotatif tangerang selanjutnya disebut pembeli para',
#   {'entities': [(61, 101, 'no_ajb'),
#     (675, 691, 'penjual_nama'),
#     (695, 723, 'penjual_pekerjaan'),
#     (724, 749, 'penjual_kewarganegaraan'),
#     (753, 844, 'penjual_alamat'),
#     (1009, 1023, 'pembeli_nama'),
#     (1039, 1056, 'pembeli_pekerjaan'),
#     (1057, 1081, 'pembeli_kewarganegaraan'),
#     (1086, 1169, 'pembeli_alamat')]}),
#  ('AJB1_1989_D_3\tmengenai jual beli tanah hak milik adat nomor akta jual beli n0 358 agr jb 19 89 kamis 06 april datang menghadap kepada kami aclimakosasihba camat kepala wilayah kecamatan pada hari ini hari 89 19 tanggal cipondo h olehmenteridalamnegeridengansuratkeputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri he en tanggalw w agraria no 101961 bertindak sebagai wwww19ynemorm ditunjuk penjabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no10 kecamatan cipondron 1961 tentang pendaftaran tanah untuk wilayah dengan dihadliri oleh saksisaksi yang kami kenaldiperkenalkan kepada kami dan akan dise butkan dibagian akhir akta ini naaa fajar pirhska u m u r 35 tahun pelcerjean pialang saham  koorwgmm indanesta ei jalan raya pasar kemis rt 03 rw 01 kutajaya pasarkemis gelam jaya pasarkemis tangerang banten wa ded am hatint bertindak untut diri gendirf dan besagat kuaga waris darf aimerhum taip riđan geguet rat kuagatgt november 1988g waw selanjutnya disebut penjual s nama jaka perkasa ii wun6ts inun pekerjean pelajar kewarganegaraan indđ che gin ja1 amat heryano rioc2ah09 terurahan sukagari kecamatan tangerang kotatif tangerang selanjutnya disebut pembeli para',
#   {'entities': [(60, 94, 'no_ajb'),
#     (675, 693, 'penjual_nama'),
#     (694, 710, 'penjual_umur'),
#     (711, 735, 'penjual_pekerjaan'),
#     (737, 755, 'penjual_kewarganegaraan'),
#     (759, 852, 'penjual_alamat'),
#     (1017, 1034, 'pembeli_nama'),
#     (1050, 1067, 'pembeli_pekerjaan'),
#     (1068, 1092, 'pembeli_kewarganegaraan'),
#     (1097, 1180, 'pembeli_alamat')]}),
#  ('AJB1_1989_D_4\tmengenai jual beli tanah hak milik adat nomor akta jual beli no 58 jbagr 1989 kamis 06 april datang menghadap kepada kami aclimakosasihba camat kepala wilayah kecamatan pada hari ini hari 89 19 tanggal cipondo h olehmenteridalamnegeridengansuratkeputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri he en tanggalw w agraria no 101961 bertindak sebagai wwww19ynemorm ditunjuk penjabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no10 kecamatan cipondron 1961 tentang pendaftaran tanah untuk wilayah dengan dihadliri oleh saksisaksi yang kami kenaldiperkenalkan kepada kami dan akan dise butkan dibagian akhir akta ini nama akb ar tan j0ung umur 23 tahun pekerjaan buruh pabrik kewarganegaraan indanesta alamat taman royal 3 jl palem 4 no 32 poris plawad cipondoh tangerang banten dengan ini bertindak untut diri sendiri dan sebagai kuasa waris dari almarhum taip ridan sesuai surat kuasa tgl 22 november 1988 selanjutnya disebut penjual nama robert partys0n umur 35 tahun pekerjean mahasiswa kewarganegaraan indonesia alamat gin ja1 heryano rioc2ah09 terurahan sukasari kecamatan tangerang kotatif tangerang selanjutnya disebut pembeli para',
#   {'entities': [(60, 91, 'no_ajb'),
#     (672, 693, 'penjual_nama'),
#     (694, 707, 'penjual_umur'),
#     (708, 730, 'penjual_pekerjaan'),
#     (731, 756, 'penjual_kewarganegaraan'),
#     (757, 833, 'penjual_alamat'),
#     (991, 1011, 'pembeli_nama'),
#     (1012, 1025, 'pembeli_umur'),
#     (1026, 1045, 'pembeli_pekerjaan'),
#     (1046, 1071, 'pembeli_kewarganegaraan'),
#     (1072, 1161, 'pembeli_alamat')]}),
#  ('AJB1_1989_D_5\tmengenai jual beli tanah hak milik adat nomor akta jual beli n0 1789 agr jb 8919 kamis 06 april datang menghadap kepada kami aclimakosasihba camat kepala wilayah kecamatan pada hari ini hari 89 19 tanggal cipondo h olehmenteridalamnegeridengansuratkeputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri he en tanggalw w agraria no 101961 bertindak sebagai wwww19ynemorm ditunjuk penjabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no10 kecamatan cipondron 1961 tentang pendaftaran tanah untuk wilayah dengan dihadliri oleh saksisaksi yang kami kenaldiperkenalkan kepada kami dan akan dise butkan dibagian akhir akta ini nama anni sa rahm a umur 29 tahun pekerjaan penulis kewarganegaraan indanesta alamat jl industri raya iii facto blok e no12 12a dengan ini bertindak untut diri sendiri dan sebagai kuasa waris dari almarhum taip ridan sesuai surat kuasa tgl 22 november 1988 selanjutnya disebut penjual nama jaka perkasa umur 30 tahun pekerjean mahasiswa kewarganegaraan indonesia alamat gin ja1 heryano rioc2ah09 terurahan sukasari kecamatan tangerang kotatif tangerang selanjutnya disebut pembeli para',
#   {'entities': [(60, 94, 'no_ajb'),
#     (675, 694, 'penjual_nama'),
#     (695, 708, 'penjual_umur'),
#     (709, 726, 'penjual_pekerjaan'),
#     (727, 752, 'penjual_kewarganegaraan'),
#     (753, 802, 'penjual_alamat'),
#     (960, 977, 'pembeli_nama'),
#     (978, 991, 'pembeli_umur'),
#     (992, 1011, 'pembeli_pekerjaan'),
#     (1012, 1037, 'pembeli_kewarganegaraan'),
#     (1038, 1127, 'pembeli_alamat')]}),
#  ('AJB1_1989_D_6\tmengenai jual beli tanah hak milik adat nomor akta beli jual no 1789 jbagr 19 89 kamis 06 april datang menghadap kepada kami aclimakosasihba camat kepala wilayah kecamatan pada hari ini hari 89 19 tanggal cipondo h olehmenteridalamnegeridengansuratkeputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri he en tanggalw w agraria no 101961 bertindak sebagai wwww19ynemorm ditunjuk penjabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no10 kecamatan cipondron 1961 tentang pendaftaran tanah untuk wilayah dengan dihadliri oleh saksisaksi yang kami kenaldiperkenalkan kepada kami dan akan dise butkan dibagian akhir akta ini na a m sury4 saputrai u u u m r 35 tahun pegawai sipil pelcerjan kewarganegaraan indooneesia a l m a a t jl kameswara 3 no 4 cibodas baru cibodas tangerang dengan ini bertindak untut diri sendiri dan sebagai kuasa waris dari almarhum taip ridan sesuai surat kuasa tgl 22 november 1988 selanjutnya disebut penjual nama mega bintang u m ur 19 tahun pekerjean kewarganegaraan alamat mahasiswa indonesia jl gin ja1 heryano rioc2ah09 terurahan sukasari kecamatan tangerang kotatif tangerang selanjutnya disebut pembeli para',
#   {'entities': [(60, 94, 'no_ajb'),
#     (675, 696, 'penjual_nama'),
#     (697, 715, 'penjual_umur'),
#     (716, 739, 'penjual_pekerjaan'),
#     (740, 767, 'penjual_kewarganegaraan'),
#     (768, 830, 'penjual_alamat'),
#     (988, 1005, 'pembeli_nama'),
#     (1006, 1021, 'pembeli_umur'),
#     (1055, 1064, 'pembeli_pekerjaan'),
#     (1065, 1074, 'pembeli_kewarganegaraan'),
#     (1075, 1160, 'pembeli_alamat')]}),
#  ('AJB1_1989_D_7\tmengenai jual beli tanah hak milik adat nomor akta beli jual no 45 89 jr agb 1989 kamis 06 april datang menghadap kepada kami aclimakosasihba camat kepala wilayah kecamatan pada hari ini hari 89 19 tanggal cipondo h olehmenteridalamnegeridengansuratkeputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri he en tanggalw w agraria no 101961 bertindak sebagai wwww19ynemorm ditunjuk penjabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no10 kecamatan cipondron 1961 tentang pendaftaran tanah untuk wilayah dengan dihadliri oleh saksisaksi yang kami kenaldiperkenalkan kepada kami dan akan dise butkan dibagian akhir akta ini naam paloh rizal umur 26 tahun insinyur pelcerjan kewarganegaraan indooneesia a l m a a t jl kalasan raya no 55 bencongan kelapa dua kab tangerang banten 15811 dengan ini bertindak untut diri sendiri dan sebagai kuasa waris dari almarhum taip ridan sesuai surat kuasa tgl 22 november 1988 selanjutnya disebut penjual n aditya sofyan a ma u m ur 19tal tahun peljekaan kewarganegaraan alamat mahasiswa indonesia jl gin ja1 heryano rioc2ah09 terurahan sukasari kecamatan tangerang kotatif tangerang selanjutnya disebut pembeli para',
#   {'entities': [(60, 95, 'no_ajb'),
#     (676, 692, 'penjual_nama'),
#     (693, 706, 'penjual_umur'),
#     (707, 725, 'penjual_pekerjaan'),
#     (726, 753, 'penjual_kewarganegaraan'),
#     (754, 835, 'penjual_alamat'),
#     (995, 1008, 'pembeli_nama'),
#     (1014, 1032, 'pembeli_umur'),
#     (1066, 1075, 'pembeli_pekerjaan'),
#     (1076, 1085, 'pembeli_kewarganegaraan'),
#     (1086, 1171, 'pembeli_alamat')]}),
#  ('AJB1_1989_D_8\tmengenai jual beli tanah hak milik adat nomor c3603 akta jual beli no 78 agr jb 88 19 pada hari ini hari selasa tanggal 15 november 1988 datang menghadap kepada kami m luthfi hanafie ba camat kepala wilayah kecamatan cipondoh oleh menteri dalam negeri dengan surat keputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri tanggal 10 nomor agraria no 10 1961 bertindak 1 sebagai ditunjuk pejabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kabupaten daerah tingkat ii tangerang dengan dihadiri oleh saksi saksi yang kami kenal diperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini i nama muhamad ilham sodikin umur 39 tahun  pekerjaan karyawan bank swasta kewarganegaraan indonesia alamat jl palem raya no13 blok xi perumnas i cibodas cibodasari tangerang banten selanjutnya disebut penjual nama jaka pihrkasa u m ur 19 tahun pekerjaan pelajar kewarganegaraan indonesia alamat jl mt haryono rt 002 09 kelurahan sukasari kecamatan tangerang kota 2 administratif tangerang selanjutnya disebut pembeli para',
#   {'entities': [(66, 99, 'no_ajb'),
#     (707, 733, 'penjual_nama'),
#     (734, 747, 'penjual_umur'),
#     (748, 779, 'penjual_pekerjaan'),
#     (780, 805, 'penjual_kewarganegaraan'),
#     (806, 886, 'penjual_alamat'),
#     (915, 933, 'pembeli_nama'),
#     (934, 949, 'pembeli_umur'),
#     (950, 967, 'pembeli_pekerjaan'),
#     (968, 993, 'pembeli_kewarganegaraan'),
#     (994, 1094, 'pembeli_alamat')]}),
#  ('AJB1_1989_D_9\tmengenai jual beli tanah hak milik adat nomor c3603 akta jual beli no 1162 jb agr 1988 pada hari ini hari selasa tanggal 15 november 1988 datang menghadap kepada kami m luthfi hanafie ba camat kepala wilayah kecamatan cipondoh oleh menteri dalam negeri dengan surat keputusannya berdasarkan ketentuan dalam pasal 5 peraturan menteri tanggal 10 nomor agraria no 10 1961 bertindak 1 sebagai ditunjuk pejabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kabupaten daerah tingkat ii tangerang dengan dihadiri oleh saksi saksi yang kami kenal diperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini i ny rizka az zhra nama 25 tahun u mur pengusaha pel0ekejan indonesia kewarganegaraan jl benteng betawi ruko cendana taman royal no35 tanah tinggi tangerang banten alamat selanjutnya disebut penjual jaka pihrkasa nama 19 tahun u m ur pelajar pekerjaan indonesia kewarganegaraan jl mt haryono rt 002 09 kelurahan sukasari kecamatan alamat tangerang kota 2 administratif tangerang selanjutnya disebut pembeli para',
#   {'entities': [(66, 100, 'no_ajb'),
#     (708, 729, 'penjual_nama'),
#     (730, 744, 'penjual_umur'),
#     (745, 765, 'penjual_pekerjaan'),
#     (766, 791, 'penjual_kewarganegaraan'),
#     (792, 876, 'penjual_alamat'),
#     (905, 923, 'pembeli_nama'),
#     (924, 939, 'pembeli_umur'),
#     (940, 957, 'pembeli_pekerjaan'),
#     (958, 983, 'pembeli_kewarganegaraan'),
#     (983, 1084, 'pembeli_alamat')]}),
#  ('AJB1_1989_D_10\tmengenai jualbeli tanah hak mi ik adat nomor 36 c03 akta jualbali 62jbagr no 88 19 pada hari ini hari selasa tanggal 15 november 1988 datang menghadap kepada kami m luthfi hanafie ba camat kepala wilayah kecamatan c1pondth olehmenteridalamnegeri dengan suratkeputusannya berdasarkan ketentuan dalam pasal 5 menteri peraturan tanggal 10 nomor agraria no 10 1961 bertindak 1 sebagai ditunjuk pejabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kabupaten daerah tingkat ii tangerang dengan dihadiri oleh saksi saksi yang kami kenal diperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini i ny rini soemantri nama 49tah u mur ibu rumah tangga pekerajan indonesia kewarganegaraan a al Jl Honoris Raya Kav 6 Kompleks Modernland aal tam selanjutnya disebut penjual jaka pihrkasa nama 19 tahun u m ur pelajar pekerjaan indonesia kewarganegaraan jl mt haryono rt 002 09 kelurahan sukasari kecamatan alamat tangerang kota 2 administratif tangerang selanjutnya disebut pembeli para',
#   {'entities': [(60, 97, 'no_ajb'),
#     (701, 723, 'penjual_nama'),
#     (724, 735, 'penjual_umur'),
#     (736, 762, 'penjual_pekerjaan'),
#     (763, 788, 'penjual_kewarganegaraan'),
#     (789, 843, 'penjual_alamat'),
#     (872, 890, 'pembeli_nama'),
#     (891, 906, 'pembeli_umur'),
#     (907, 924, 'pembeli_pekerjaan'),
#     (924, 950, 'pembeli_kewarganegaraan'),
#     (951, 1051, 'pembeli_alamat')]}),
#  ('AJB1_1990_D_1\tpembeli akta jual beli 361 no cipondoh 1990 rabu tanggal 28 maret 1990 pada hari ini datang menghadap kepada saya achmad kosasir ba camat kepala wilayah kecamatan i f ondoh oleh menteri dalam negerikepala badan pertanahan nasional dengan surat berdasarkan ketentuan dalam pasal 5 peraturan menteri agraria no 101961 keputusannya tanggal no bertindak sebagai pejabat pembuat akta tanah yang dimaksud dalam diangkat pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kecamatan cipondoh dengan dihadiri oleh saksisaksi yang dikenal oleh saya pejabat pembuat akta tanah dan akan disebutkan di bagian akhir akta ini i nama suwarman 85 t ahun petani umur pekerjaan kewarganegaraan indonesia jldaan mogot 59 a lama t selaku penjual untuk selanjutnga di setut pihak pertama satria wibawa ii tama 24 t a h u n vmur mahasiswa pekerjean kewargane paraan ind onesia jh m haryono rt02rw09 kelurahan sukasari a 1amat kecamatan tangerang kotif tangarang selaku pembeli untuk selanjutnya di sebut pifak kedua',
#   {'entities': [(22, 57, 'no_ajb'),
#     (663, 676, 'penjual_nama'),
#     (677, 686, 'penjual_umur'),
#     (687, 693, 'penjual_pekerjaan'),
#     (709, 734, 'penjual_kewarganegaraan'),
#     (735, 759, 'penjual_alamat'),
#     (816, 829, 'pembeli_nama'),
#     (838, 855, 'pembeli_umur'),
#     (856, 875, 'pembeli_pekerjaan'),
#     (876, 903, 'pembeli_kewarganegaraan'),
#     (904, 988, 'pembeli_alamat')]}),
#  ('AJB1_1990_D_2\tpembeli akta jual beli 869 no kunciran 1990 kamis tanggal 16 juni 1990 pada hari ini datang menghadap kepada saya achmad kosasir ba camat kepala wilayah kecamatan i cipondoh oleh menteri dalam negeri kepala badan pertanahan nasional dengan surat berdasarkan ketentuan dalam pasal 5 peraturan menteri agraria no 10 1961 keputusannya tanggal no bertindak sebagai pejabat pembuat akta tanah yang dimaksud dalam diangkat pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kecamatan cipondoh dengan dihadiri oleh saksi saksi yang dikenal oleh saya pejabat pembuat akta tanah dan akan disebutkan di bagian akhir akta ini i nama suwardi umur 77 tahun pekerjaan pelayan kewarganegaraan indonesia alamat jl mh thamrin kompleks mahkota mas blok e35 selaku penjual untuk selanjutnga disebut pihak pertama nama satria wibawa vmur 24 t a h u n mahasiswa pekerjean kewarganegaraan indonesia alamat jl mt haryono rt 02 rw 09 kelurahan sukasari a1amat kecamatan tangerang kotif tangarang selaku pembeli untuk selanjutnya di sebut pihak kedua',
#   {'entities': [(22, 57, 'no_ajb'),
#     (667, 679, 'penjual_nama'),
#     (680, 693, 'penjual_umur'),
#     (694, 711, 'penjual_pekerjaan'),
#     (712, 737, 'penjual_kewarganegaraan'),
#     (738, 788, 'penjual_alamat'),
#     (844, 862, 'pembeli_nama'),
#     (863, 880, 'pembeli_umur'),
#     (881, 900, 'pembeli_pekerjaan'),
#     (901, 926, 'pembeli_kewarganegaraan'),
#     (927, 1021, 'pembeli_alamat')]}),
#  ('AJB1_1990_D_3\tpembeli akta jual beli 1899 no nerogtog 1990 senin tanggal 10 maret 1990 pada hari ini datang menghadap kepada saya achmad kos asir ba c4mt kepala wilayah kecamatan ifondoh oleh menteri dalam negeri kepala badan pertanahan nasional dengan surat berdasarkan ketentuan dalam pasal 5 peraturan menteri agraria no 101961 keputusannya tanggal no bertindak sebagai pejabat pembuat akta tanah yang dimaksud dalam diangkat pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kecamatan cipondoh dengan dihadiri oleh saksisaksi yang dikenal oleh saya pejabat pembuat akta tanah dan akan disebutkan di bagian akhir akta ini i nama pekerjaan kewarganegaraan maria vania 23 tahun content creator umur indonesia jl kh hasyim ashari 24 rt 002 12 alamat selaku penjual untuk selanjutnya disebut pihak pertama naam vmur pekerjean rusdi taklim ii tama 24 tahun mahasiswa kewargane paraan indonesia jh kameswara 3 no 4 rt02rw09 kelurahan cibodas baru a 1amat kecamatan cibodas kotif tangarang selaku pembeli untuk selanjutnya disebut pihak kedua',
#   {'entities': [(22, 58, 'no_ajb'),
#     (695, 706, 'penjual_nama'),
#     (707, 715, 'penjual_umur'),
#     (716, 731, 'penjual_pekerjaan'),
#     (737, 746, 'penjual_kewarganegaraan'),
#     (747, 786, 'penjual_alamat'),
#     (862, 874, 'pembeli_nama'),
#     (883, 891, 'pembeli_umur'),
#     (892, 901, 'pembeli_pekerjaan'),
#     (902, 928, 'pembeli_kewarganegaraan'),
#     (929, 1022, 'pembeli_alamat')]}),
#  ('AJB1_1990_D_4\tpembeli akta jual beli no 1899 1990 cibodas senin tanggal 10 maret 1990 pada hari ini datang menghadap kepada saya achmad kos asir ba c4mt kepala wilayah kecamatan ifondoh oleh menteri dalam negeri kepala badan pertanahan nasional dengan surat berdasarkan ketentuan dalam pasal 5 peraturan menteri agraria no 101961 keputusannya tanggal no bertindak sebagai pejabat pembuat akta tanah yang dimaksud dalam diangkat pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kecamatan cipondoh dengan dihadiri oleh saksisaksi yang dikenal oleh saya pejabat pembuat akta tanah dan akan disebutkan di bagian akhir akta ini i nama albert park pekerjaan kewarganegaraan 59 tahun petani umur indonesia jl jendral a yani 9 alamat selaku penjual untuk selanjutnya disebut pihak pertama naam vmur pekerjean rusmansyah ii tama 32 tahun karyawan suasta kewargane paraan indonesia jh kameswara 3 no 4 rt02rw09 kelurahan cibodas baru a 1amat kecamatan cibodas kotif tangarang selaku pembeli untuk selanjutnya disebut pihak kedua',
#   {'entities': [(22, 57, 'no_ajb'),
#     (663, 679, 'penjual_nama'),
#     (706, 714, 'penjual_umur'),
#     (715, 721, 'penjual_pekerjaan'),
#     (727, 736, 'penjual_kewarganegaraan'),
#     (736, 763, 'penjual_alamat'),
#     (839, 849, 'pembeli_nama'),
#     (858, 866, 'pembeli_umur'),
#     (867, 883, 'pembeli_pekerjaan'),
#     (883, 909, 'pembeli_kewarganegaraan'),
#     (910, 1003, 'pembeli_alamat')]}),
#  ('AJB1_1990_D_5\tpembeli akta jual beli no 1899 cipete 1990 senin tanggal 10 maret 1990 pada hari ini datang menghadap kepada saya achmad kos asir ba c4mt kepala wilayah kecamatan ifondoh oleh menteri dalam negeri kepala badan pertanahan nasional dengan surat berdasarkan ketentuan dalam pasal 5 peraturan menteri agraria no 101961 keputusannya tanggal no bertindak sebagai pejabat pembuat akta tanah yang dimaksud dalam diangkat pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kecamatan cipondoh dengan dihadiri oleh saksisaksi yang dikenal oleh saya pejabat pembuat akta tanah dan akan disebutkan di bagian akhir akta ini i nama michael ottoman 41 tahun umur pekerjaan manajer bank bangunan kewarganegaraan indonesia al mat jl raya karawaci kompleks islamic village selaku penjual untuk selanjutnya disebut pihak pertama naam tafakur alam vmur 66 tahun pekerjean ii tama pensiun militer kewarganeparaan indonesia almat jh industri raya 3 fakto blok e no 12 12a selaku pembeli untuk selanjutnya disebut pihak kedua',
#   {'entities': [(22, 56, 'no_ajb'),
#     (662, 682, 'penjual_nama'),
#     (683, 696, 'penjual_umur'),
#     (697, 719, 'penjual_pekerjaan'),
#     (729, 754, 'penjual_kewarganegaraan'),
#     (755, 803, 'penjual_alamat'),
#     (859, 876, 'pembeli_nama'),
#     (877, 890, 'pembeli_umur'),
#     (891, 924, 'pembeli_pekerjaan'),
#     (925, 950, 'pembeli_kewarganegaraan'),
#     (951, 998, 'pembeli_alamat')]}),
#  ('AJB1_2008_D_1\t51 salinan pembeli akta jual beli no 1313 i 2008 lembar pertamakedua pada hari ini selase tanggal 25 dua puluh lima tahun 2008 dua ribu delapan bulan nopember hadir dihadapan saya hmasikin wirayuda sh yang berdasarkan surat keputusan kepala kanw1l badan pertanahan nasional probantennggal 20062002 nomor 640122002 diangkatditunjuk sebagai pejabat pembuat akta tanah yang selanjutnya disebut ppat yang dimaksud dalam pasal 7 peraturan pemerintah nomor 24 tahun 1997 tentang pendaftaran tanah dengan daerah kerja kecamatan pinang kunciran jaya kecanatan pinangtangeranglengan dihadiri oleh dan berkantor di jlhrrasuna said kelurahan saksisaksi yang saya kenal dan akan disebut pada bagian akhir akta ini i tuan ibrohim b hsarim lahir tangerang8 agustus 1963 warga negara indonesia agama islam pekerjaan karyawan swasta bertempat tinggal rukun tetangga 02 rukun werga 03 kelurahan kunciran jaya kecamatan pinang kota tangerang propinsi banten dalam hal ini bertindak sebagai kuasa waris dari almarhum tuanhsarīmb djiman sesuai surat kuasa waris dan surat keterangan waris nomor 595558kemasykj2008 tanggal 13 nopenber 2003 selaku penjualselanjutnya disebut pihak pertama ii tuans w ahyudi n lahir tangerang 20 mei 1975 warga negara indonesia agama islam pekerjaan pegawai swasta bertempat tinggal jalan mt haryono rukun tetangga 02 rukun warga 09 kelurahan sukasari kecamatan tangerang kota tangerang propinsi banten selaku pembeliselanjutnya disebut pihak kedua halaman i dari7 akta jual bell',
#   {'entities': [(33, 62, 'no_ajb'),
#     (718, 739, 'penjual_nama'),
#     (740, 769, 'penjual_umur'),
#     (770, 792, 'penjual_kewarganegaraan'),
#     (793, 804, 'penjual_agama'),
#     (805, 830, 'penjual_pekerjaan'),
#     (831, 953, 'penjual_alamat'),
#     (1184, 1200, 'pembeli_nama'),
#     (1201, 1228, 'pembeli_umur'),
#     (1229, 1251, 'pembeli_kewarganegaraan'),
#     (1252, 1263, 'pembeli_agama'),
#     (1264, 1288, 'pembeli_pekerjaan'),
#     (1289, 1426, 'pembeli_alamat')]}),
#  ('AJB1_2008_D_2\tsalinan pembeli akta jual beli no 1358 2008 lembar pertama/kedua pada hari ini, minggu  tanggal 06 bulan april tahun 2008 datang menghadap kepada saya h m as1ikin wirayuda s h berdasarkan surat keputusan kepala kanwil badan pertanahan nasional pro banten tanggal 20062002 ketentuan dalam pasal 5 peraturan menteri he en tanggalw w agraria no 101961 bertindak sebagai wwww19ynemorm ditunjuk penjabat pembuat akta tanah yang dimaksudkan dalam pasal 19 peraturan pemerintah no10 kecamatan cipondron 1961 tentang pendaftaran tanah untuk wilayah dengan dihadliri oleh saksisaksi yang kami kenaldiperkenalkan kepada kami dan akan disebutkan dibagian akhir akta ini tuan mila meliko lahir 2 mei 1977 warga negara indonesia agama kristen protestan pekerjaan karyawan swasta bertempat tinggal jl manis raya kawasan industri manis rt 003 01 curug dengan ini bertindak untut diri sendiri dan sebagai kuasa waris dari almarhum taip ridan sesuai surat kuasa tgl 22 november 1988 selanjutnya disebut penjual nama jaka perkasa umur 19 tahun pekerjean mahasiswa kewarganegaraan indonesia alamat gin ja1 heryano rioc2ah09 terurahan sukasari kecamatan tangerang kotatif tangerang selanjutnya disebut pembeli para',
#   {'entities': [(30, 57, 'no_ajb'),
#     (673, 689, 'penjual_nama'),
#     (690, 706, 'penjual_umur'),
#     (707, 729, 'penjual_kewarganegaraan'),
#     (730, 753, 'penjual_agama'),
#     (754, 779, 'penjual_pekerjaan'),
#     (780, 850, 'penjual_alamat'),
#     (1008, 1025, 'pembeli_nama'),
#     (1026, 1039, 'pembeli_umur'),
#     (1040, 1059, 'pembeli_pekerjaan'),
#     (1060, 1085, 'pembeli_kewarganegaraan'),
#     (1086, 1175, 'pembeli_alamat')]}),
#  ('AJB1_2008_D_3\t51 salinan pembeli akta jual beli no 113 2008 lembar pertama kedua pada hari ini selase tanggal 25 dua puluh lima tahun 2008 dua ribu delapan bulan nopember hadir dihadapan saya hmasikin wirayuda sh yang berdasarkan surat keputusan kepala kanw1l badan pertanahan nasional probantennggal 20062002 nomor 640122002 diangkatditunjuk sebagai pejabat pembuat akta tanah yang selanjutnya disebut ppat yang dimaksud dalam pasal 7 peraturan pemerintah nomor 24 tahun 1997 tentang pendaftaran tanah dengan daerah kerja kecamatan pinang kunciran jaya kecanatan pinangtangeranglengan dihadiri oleh dan berkantor di jlhrrasuna said kelurahan saksisaksi yang saya kenal dan akan disebut pada bagian akhir akta ini i tuan andre taulany lahir tangerang22 desember 1961 warga negara indonesia agama buddha pekerjaan buruh pabrik bertempat tinggal rukun tetangga 05 rukun werga 02 kelurahan kunciran jaya kecamatan pinang kota tangerang propinsi banten dalam hal ini bertindak sebagai kuasa waris dari almarhum tuanhsarīmb djiman sesuai surat kuasa waris dan surat keterangan waris nomor 595558kemasykj2008 tanggal 13 nopenber 2003 selaku penjualselanjutnya disebut pihak pertama ii tuan wahyudi n lahir tangerang 17 februari 1970 warga negara indonesia agama islam pekerjaan pegawai swasta bertempat tinggal jalan mt haryono rukun tetangga 02 rukun warga 09 kelurahan sukasari kecamatan tangerang kota tangerang propinsi banten selaku pembeliselanjutnya disebut pihak kedua halaman i dari7 akta jual bell',
#   {'entities': [(33, 59, 'no_ajb'),
#     (716, 734, 'penjual_nama'),
#     (735, 766, 'penjual_umur'),
#     (767, 789, 'penjual_kewarganegaraan'),
#     (790, 802, 'penjual_agama'),
#     (803, 825, 'penjual_pekerjaan'),
#     (826, 948, 'penjual_alamat'),
#     (1179, 1193, 'pembeli_nama'),
#     (1194, 1226, 'pembeli_umur'),
#     (1227, 1249, 'pembeli_kewarganegaraan'),
#     (1250, 1261, 'pembeli_agama'),
#     (1262, 1286, 'pembeli_pekerjaan'),
#     (1287, 1424, 'pembeli_alamat')]})]

# %% [markdown]
# # Create the model for AJB document page one

# %%
import spacy
import random
import datetime
from spacy.training.example import Example
from spacy.scorer import Scorer

# %%
# create the spacy pipeline and define the label
nlp = spacy.blank("id")
ner = nlp.add_pipe('ner')

ner.add_label("no_ajb")
ner.add_label("penjual_nama")
ner.add_label("penjual_umur")
ner.add_label("penjual_pekerjaan")
ner.add_label("penjual_agama")
ner.add_label("penjual_kewarganegaraan")
ner.add_label("penjual_alamat")
ner.add_label("pembeli_nama")
ner.add_label("pembeli_umur")
ner.add_label("pembeli_pekerjaan")
ner.add_label("pembeli_agama")
ner.add_label("pembeli_kewarganegaraan")
ner.add_label("pembeli_alamat")

print(ner.move_names)
# Out:
# ['B-no_ajb', 'I-no_ajb', 'L-no_ajb', 'U-no_ajb', 'B-penjual_nama', 'I-penjual_nama', 'L-penjual_nama', 'U-penjual_nama', 'B-penjual_umur', 'I-penjual_umur', 'L-penjual_umur', 'U-penjual_umur', 'B-penjual_pekerjaan', 'I-penjual_pekerjaan', 'L-penjual_pekerjaan', 'U-penjual_pekerjaan', 'B-penjual_agama', 'I-penjual_agama', 'L-penjual_agama', 'U-penjual_agama', 'B-penjual_kewarganegaraan', 'I-penjual_kewarganegaraan', 'L-penjual_kewarganegaraan', 'U-penjual_kewarganegaraan', 'B-penjual_alamat', 'I-penjual_alamat', 'L-penjual_alamat', 'U-penjual_alamat', 'B-pembeli_nama', 'I-pembeli_nama', 'L-pembeli_nama', 'U-pembeli_nama', 'B-pembeli_umur', 'I-pembeli_umur', 'L-pembeli_umur', 'U-pembeli_umur', 'B-pembeli_pekerjaan', 'I-pembeli_pekerjaan', 'L-pembeli_pekerjaan', 'U-pembeli_pekerjaan', 'B-pembeli_agama', 'I-pembeli_agama', 'L-pembeli_agama', 'U-pembeli_agama', 'B-pembeli_kewarganegaraan', 'I-pembeli_kewarganegaraan', 'L-pembeli_kewarganegaraan', 'U-pembeli_kewarganegaraan', 'B-pembeli_alamat', 'I-pembeli_alamat', 'L-pembeli_alamat', 'U-pembeli_alamat']

# %%
# initialize the training
nlp.begin_training()

other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]

epochs = 1000
print("current date: {0} {1} {2}".format(datetime.datetime.now().day, datetime.datetime.now().strftime("%B"), datetime.datetime.now().year))
with nlp.disable_pipes(*other_pipes): # only train NER    
    for i in range(epochs):
        random.shuffle(training_data_ajb_1)
        losses = {}

        for batch in spacy.util.minibatch(training_data_ajb_1, size=2):
            for text, entities in batch:
                doc = nlp.make_doc(text)
                example = Example.from_dict(doc, entities)

                nlp.update([example], losses=losses, drop=0.3)

        print("iteration: {0} | loss: {1} | time: {2}".format(i + 1, losses, datetime.datetime.now().strftime("%H:%M:%S")))
    
# save the result of training into disk
nlp.to_disk("ajb_1_model")
# Out:
# current date: 14 7 2021
# /home/msultont/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "AJB1_1988_D_3	mengenai jual beli tanah hak milik a..." with entities "[(66, 99, 'no_ajb'), (711, 729, 'penjual_nama'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/msultont/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "AJB1_1990_D_4	pembeli akta jual beli no 1899 1990 ..." with entities "[(22, 57, 'no_ajb'), (663, 679, 'penjual_nama'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/msultont/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "AJB1_1988_D_8	mengenai jual beli tanah hak milik a..." with entities "[(67, 101, 'no_ajb'), (709, 731, 'penjual_nama'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/msultont/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "AJB1_1988_R_1	mengenai jual bali ml ik adat tanah ..." with entities "[(66, 97, 'no_ajb'), (710, 718, 'penjual_umur'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_32373/466126523.py in <module>
#      16                 example = Example.from_dict(doc, entities)
#      17
# ---> 18                 nlp.update([example], losses=losses, drop=0.3)
#      19
#      20         print("iteration: {0} | loss: {1} | time: {2}".format(i + 1, losses, datetime.datetime.now().strftime("%H:%M:%S")))
#
# ~/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/language.py in update(self, examples, _, drop, sgd, losses, component_cfg, exclude)
#    1110             if name in exclude or not hasattr(proc, "update"):
#    1111                 continue
# -> 1112             proc.update(examples, sgd=None, losses=losses, **component_cfg[name])
#    1113         if sgd not in (None, False):
#    1114             for name, proc in self.pipeline:
#
# ~/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser.update()
#
# ~/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser._init_gold_batch()
#
# ~/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/pipeline/_parser_internals/transition_system.pyx in spacy.pipeline._parser_internals.transition_system.TransitionSystem.get_oracle_sequence_from_state()
#
# ~/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/pipeline/_parser_internals/ner.pyx in spacy.pipeline._parser_internals.ner.BiluoPushDown.set_costs()
#
# ValueError:

# %% [markdown]
# # Create the model for AJB document page two and three

# %%
# create the spacy pipeline and define the label
nlp_new = spacy.blank("id")
ner_new = nlp_new.add_pipe('ner')
ner_new.add_label("no_kohir_girik")
ner_new.add_label("no_persil")
ner_new.add_label("provinsi_tanah")
ner_new.add_label("kabupaten_tanah")
ner_new.add_label("kecamatan_tanah")
ner_new.add_label("kelurahan_tanah")
ner_new.add_label("jalan_tanah")
ner_new.add_label("harga_tanah")
ner_new.add_label("luas_tanah")
# Out:
# 1

# %%
# initialize the training
nlp_new.begin_training()

epochs = 1000
print("current date: {0} {1} {2}".format(datetime.datetime.now().day, datetime.datetime.now().strftime("%B"), datetime.datetime.now().year))
for i in range(epochs):
    random.shuffle(training_data_ajb_23)
    losses = {}
    
    for batch in spacy.util.minibatch(training_data_ajb_23, size=2):
        for text, entities in batch:
            doc = nlp.make_doc(text)
            example = Example.from_dict(doc, entities)
            
            nlp_new.update([example], losses=losses, drop=0.3)
    
    print("iteration: {0} | loss: {1} | time: {2}".format(i + 1, losses, datetime.datetime.now().strftime("%H:%M:%S")))
    
# save the result of training into disk
nlp_new.to_disk("ajb_23_model")
# Out:
# current date: 14 July 2021
# /home/msultont/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "AJB2_1990_D_1	2 para penghadap dikenal oleh saya p..." with entities "[(413, 429, 'no_persil'), (449, 463, 'no_kohir_gir...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/msultont/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "AJB2_2008_D_1	para penghadap dikenal oleh sayapeng..." with entities "[(909, 926, 'no_persil'), (926, 953, 'no_kohir_gir...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/msultont/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "AJB2_2008_R_1	para penghadap dikenal oleh sayapeng..." with entities "[(909, 926, 'no_persil'), (926, 953, 'no_kohir_gir...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# iteration: 0 | loss: {'ner': 1400.7767565379474} | time: 06:31:36
# {'ner': 1400.7767565379474}
# iteration: 1 | loss: {'ner': 1871.6770718947769} | time: 06:31:39
# {'ner': 1871.6770718947769}
# iteration: 2 | loss: {'ner': 1568.189440515658} | time: 06:31:41
# {'ner': 1568.189440515658}
# iteration: 3 | loss: {'ner': 1326.94483246237} | time: 06:31:44
# {'ner': 1326.94483246237}
# iteration: 4 | loss: {'ner': 1282.5966826176402} | time: 06:31:47
# {'ner': 1282.5966826176402}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_22110/1765383941.py in <module>
#      13             example = Example.from_dict(doc, entities)
#      14
# ---> 15             x = nlp.update([example], losses=losses, drop=0.3)
#      16
#      17     print("iteration: {0} | loss: {1} | time: {2}".format(i, losses, datetime.datetime.now().strftime("%H:%M:%S")))
#
# ~/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/language.py in update(self, examples, _, drop, sgd, losses, component_cfg, exclude)
#    1110             if name in exclude or not hasattr(proc, "update"):
#    1111                 continue
# -> 1112             proc.update(examples, sgd=None, losses=losses, **component_cfg[name])
#    1113         if sgd not in (None, False):
#    1114             for name, proc in self.pipeline:
#
# ~/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser.update()
#
# ~/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/thinc/model.py in begin_update(self, X)
#     307         and returns the gradient with respect to the input.
#     308         """
# --> 309         return self._func(self, X, is_train=True)
#     310
#     311     def predict(self, X: InT) -> OutT:
#
# ~/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/spacy/ml/parser_model.pyx in spacy.ml.parser_model.step_forward()
#
# ~/Desktop/project-seighneur/SDTR/model/lib/python3.9/site-packages/thinc/model.py in attrs(self)
#     114         return self._shims
#     115
# --> 116     @property
#     117     def attrs(self) -> Dict[str, Any]:
#     118         """A dict of the model's attrs. You can write to it to update attrs but
#
# KeyboardInterrupt:

# %% [markdown]
# # Test with real data

# %%
from spacy import displacy

# Test for AJB document page one
nlp = spacy.load("./ajb_1.model/")

example = "53 pembeli akta jual beli 361 no cipondoh 19 90 rabu tanggal 28 maret 1990 pada hari ini datang menghadap kepada saya achmad kosabir ba camat kepala wilayah kecamatan i fon oh oleh menteri dalam negerikepala badan pertanahan nasional dengan surat berdasarkan ketentuan dalam pasal 5 peraturan menteri agraria no 101961 keputusannya tanggal no bertindak sebagai pejabat pembuat akta tanah yang dimaksud dalam diangkat pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kecamatan ipondoh dengan dihadiri oleh saksisaksi yang dikenal oleh saya pejabat pembuat akta tanah dan akan disebutkan di bagian akhir akta ini i n ama songgo bin bregud 85 t a h un petan i umur pekerjaan kewarganegaraan indonesia a l ama t kpkunciran rt01kw07 kelurahan kunciran kecamatan cipondoh kotif tangerang selaku penjual untuk selanjutnga di setut pihak pertama satria wibawa 24 t a h u n mahasiswa ii hama vmur pelkerjean kewargnno paraan indonesia a 1 anat j m haryono rt02rw09 kelurahan sukasari kocamatan tangerang kotif tangerang selaku pembeli untuk selanjutnya di sebut pifak kedua"
doc = nlp(example)

displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">53 pembeli
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     akta jual beli 361 no cipondoh 19 90
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">no_ajb</span>
# </mark>
#  rabu tanggal 28 maret 1990 pada hari ini datang menghadap kepada saya achmad kosabir ba camat kepala wilayah kecamatan i fon oh oleh menteri dalam negerikepala badan pertanahan nasional dengan surat berdasarkan ketentuan dalam pasal 5 peraturan menteri agraria no 101961 keputusannya tanggal no bertindak sebagai pejabat pembuat akta tanah yang dimaksud dalam diangkat pasal 19 peraturan pemerintah no 10 tahun 1961 tentang pendaftaran tanah untuk wilayah kecamatan ipondoh dengan dihadiri oleh saksisaksi yang dikenal oleh saya pejabat pembuat akta tanah dan akan disebutkan di bagian akhir akta ini i n
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ama songgo bin bregud
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">penjual_nama</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     85 t a h un petan i umur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">penjual_umur</span>
# </mark>
#  pekerjaan
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kewarganegaraan indonesia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">penjual_kewarganegaraan</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a l ama t kpkunciran rt01kw07 kelurahan kunciran kecamatan cipondoh kotif tangerang
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">pembeli_alamat</span>
# </mark>
#  selaku penjual untuk selanjutnga di setut pihak pertama
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     satria wibawa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">pembeli_nama</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     24 t a h u n
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">pembeli_umur</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mahasiswa ii hama vmur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">pembeli_pekerjaan</span>
# </mark>
#  pelkerjean
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kewargnno paraan indonesia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">penjual_kewarganegaraan</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a 1 anat j m haryono rt02rw09 kelurahan sukasari kocamatan tangerang kotif tangerang
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">penjual_alamat</span>
# </mark>
#  selaku pembeli untuk selanjutnya di sebut pifak kedua</div></span>

# %%
# Test for AJB document page two and three
nlp = spacy.load("./ajb_23.model/")

example = "2 para penghadap menerangkan bahwa penjual dengan akta ini menjual kepada pembeli dan pembeli membeli dari penjual c 246 sabidang no tanah hak mll1k adat sebahagian dari terletak di daerah tingkat iwilayah daerah tingkat ii wilayah kecamatan wilayah jawa berat clp ond oh kunciran desa tgl no m2 diuraikan dalam surat ukur luas tanah meter persegi meter erpat ratus n berukuran panjang kuranglebih lebar kuranglebih 46 d ii kohir nomor meter blok persil nomor dan berbatasan di sebelah borbatagan dengen tenah sdr saun berbatagan dengan tener cdrsim berbatagan dengen tamah hy utara timur selatan barat berbatagn dengan tanh 36y hiat selanjutnya para penghadap menerangkan bahwa jualbeli ini meliputi pula bangunan dan tanaman yang ada di atas tanah tersebut yaitu berupa tanah k ogang 1000000 bahwa jualbeli ini terjadi dengan harga rp satu jutà rupiah bahwa penjual mengaku telah menerima sepenuhnya uang pembelian tersebut di atas dan untuk penerimaan uang itu akta ini berlaku pula sebagai tanda penerimaannya kwitansi bahwa jualbeli ini dilakukan dengan syaratsyarat seperti berikut pasal 1 mulai hari ini tanah hak dan bangunancertatanaman yang diuraikan dalam akta ini telah diserahkan kepada pembeli yang mengaku pula telah merterima penyerahan itu dan segala keuntungan yang didapat dari serta segala kerugianbeban yang diderita atas tanah hak danbangunaneertatanaman tersebut di atas menjadi hak tanggungan pembeli pasal 2 penjual menjamin bahwa tanahhak dabangunansertatanaman 1 tersebut di atas tidak dikenakan sesuatu sitaan atau tersangkut sebagai tang gungan untuk sesuatu piutang atau diberati dengan bebanbeban lainnya pasal 3"
doc = nlp(example)

displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">2 para penghadap menerangkan bahwa penjual dengan akta ini menjual kepada pembeli dan pembeli membeli dari penjual c 246 sabidang no tanah hak mll1k adat sebahagian dari terletak di daerah tingkat iwilayah daerah tingkat ii wilayah kecamatan wilayah
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jawa berat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">provinsi_tanah</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     clp ond oh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">kecamatan_tanah</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kunciran desa tgl no
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">kelurahan_tanah</span>
# </mark>
#  m2 diuraikan dalam surat ukur luas tanah meter persegi meter erpat ratus n berukuran panjang kuranglebih lebar kuranglebih 46 d ii
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kohir nomor meter blok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">no_kohir_girik</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     persil nomor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">no_persil</span>
# </mark>
#  dan berbatasan di sebelah borbatagan dengen tenah sdr saun berbatagan dengan tener cdrsim berbatagan dengen tamah hy utara timur selatan barat berbatagn dengan tanh 36y hiat selanjutnya para penghadap menerangkan bahwa jualbeli ini meliputi pula bangunan dan tanaman yang ada di atas tanah tersebut yaitu berupa tanah k ogang 1000000 bahwa jualbeli ini terjadi dengan
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     harga rp satu jutà rupiah
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">harga_tanah</span>
# </mark>
#  bahwa penjual mengaku telah menerima sepenuhnya uang pembelian tersebut di atas dan untuk penerimaan uang itu akta ini berlaku pula sebagai tanda penerimaannya kwitansi bahwa jualbeli ini dilakukan dengan syaratsyarat seperti berikut pasal 1 mulai hari ini tanah hak dan bangunancertatanaman yang diuraikan dalam akta ini telah diserahkan kepada pembeli yang mengaku pula telah merterima penyerahan itu dan segala keuntungan yang didapat dari serta segala kerugianbeban yang diderita atas tanah hak danbangunaneertatanaman tersebut di atas menjadi hak tanggungan pembeli pasal 2 penjual menjamin bahwa tanahhak dabangunansertatanaman 1 tersebut di atas tidak dikenakan sesuatu sitaan atau tersangkut sebagai tang gungan untuk sesuatu piutang atau diberati dengan bebanbeban lainnya pasal 3</div></span>

# %% [markdown]
# # Evaluate the performance

# %%
from spacy.scorer import Scorer

# %%
# Evaluate score of testing data AJB document page one
ner_model = spacy.load("./ajb_1.model")
scorer = Scorer(ner_model)

examples = []
for text, entities in testing_data_ajb_1:
    doc = ner_model(text)
    example = Example.from_dict(doc, entities)
    examples.append(example)
results = scorer.score(examples)

results
# Out:
# {'token_acc': 1.0,
#  'token_p': 1.0,
#  'token_r': 1.0,
#  'token_f': 1.0,
#  'ents_p': 0.6428571428571429,
#  'ents_r': 0.5806451612903226,
#  'ents_f': 0.6101694915254238,
#  'ents_per_type': {'penjual_umur': {'p': 0.0, 'r': 0.0, 'f': 0.0},
#   'no_ajb': {'p': 0.75, 'r': 1.0, 'f': 0.8571428571428571},
#   'penjual_pekerjaan': {'p': 0.5, 'r': 0.3333333333333333, 'f': 0.4},
#   'penjual_nama': {'p': 0.3333333333333333,
#    'r': 0.3333333333333333,
#    'f': 0.3333333333333333},
#   'pembeli_nama': {'p': 1.0, 'r': 1.0, 'f': 1.0},
#   'pembeli_umur': {'p': 0.6666666666666666,
#    'r': 0.6666666666666666,
#    'f': 0.6666666666666666},
#   'penjual_alamat': {'p': 0.5, 'r': 0.5, 'f': 0.5},
#   'pembeli_alamat': {'p': 1.0, 'r': 0.3333333333333333, 'f': 0.5},
#   'pembeli_pekerjaan': {'p': 0.5, 'r': 0.3333333333333333, 'f': 0.4},
#   'penjual_kewarganegaraan': {'p': 0.6666666666666666, 'r': 1.0, 'f': 0.8},
#   'pembeli_kewarganegaraan': {'p': 1.0, 'r': 0.5, 'f': 0.6666666666666666},
#   'penjual_agama': {'p': 1.0, 'r': 1.0, 'f': 1.0},
#   'pembeli_agama': {'p': 1.0, 'r': 1.0, 'f': 1.0}}}

# %%
# Evaluate score of testing data AJB document page two and three
ner_model = spacy.load("./ajb_23.model")
scorer = Scorer(ner_model)

examples = []
for text, entities in testing_data_ajb_23:
    doc = ner_model(text)
    example = Example.from_dict(doc, entities)
    examples.append(example)
results = scorer.score(examples)

results
# Out:
# {'token_acc': 1.0,
#  'token_p': 1.0,
#  'token_r': 1.0,
#  'token_f': 1.0,
#  'ents_p': 0.6333333333333333,
#  'ents_r': 0.5,
#  'ents_f': 0.5588235294117647,
#  'ents_per_type': {'kelurahan_tanah': {'p': 0.3333333333333333,
#    'r': 0.4,
#    'f': 0.3636363636363636},
#   'kabupaten_tanah': {'p': 0.5,
#    'r': 0.6666666666666666,
#    'f': 0.5714285714285715},
#   'kecamatan_tanah': {'p': 1.0, 'r': 0.75, 'f': 0.8571428571428571},
#   'no_persil': {'p': 0.5, 'r': 0.5, 'f': 0.5},
#   'harga_tanah': {'p': 0.75, 'r': 0.5, 'f': 0.6},
#   'no_kohir_girik': {'p': 0.5, 'r': 0.2, 'f': 0.28571428571428575},
#   'luas_tanah': {'p': 1.0, 'r': 0.2, 'f': 0.33333333333333337},
#   'provinsi_tanah': {'p': 1.0, 'r': 0.75, 'f': 0.8571428571428571},
#   'jalan_tanah': {'p': 0.5, 'r': 1.0, 'f': 0.6666666666666666},
#   'no_ajb': {'p': 1.0, 'r': 1.0, 'f': 1.0}}}
